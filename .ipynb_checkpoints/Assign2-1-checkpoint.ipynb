# %%
import math
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from itertools import combinations 
df = pd.read_csv("BreadBasket_DMS_output.csv")

# %%
df.head()
# Out:
#    Year  Month  Day Weekday  Hour  Min  Sec  Transaction           Item  \
# 0  2016     10   30  Sunday     9   58   11            1          Bread
# 1  2016     10   30  Sunday    10    5   34            2   Scandinavian
# 2  2016     10   30  Sunday    10    5   34            2   Scandinavian
# 3  2016     10   30  Sunday    10    7   57            3  Hot chocolate
# 4  2016     10   30  Sunday    10    7   57            3            Jam
#
#    Item_Price
# 0        7.66
# 1        5.33
# 2        5.33
# 3        2.81
# 4        2.81

# %%
def createPeriod(hours):
    periods = []
    for hour in hours:
        if hour >= 0 and hour < 6:
            periods.append("night")
        elif hour >=6 and hour < 12:
            periods.append("morning")
        elif hour >= 12 and hour < 18:
            periods.append("afternoon")
        elif hour >= 18 and hour <= 23:
            periods.append("evening")
        else: periods.append("Nan")
    return periods

# %%
df["Period"] = createPeriod(df["Hour"])

# %%
trans_for_hour = df.groupby('Hour')['Transaction'].nunique()
busiest_hour = trans_for_hour.idxmax()

# %%
busiest_hour
# Out:
# 11

# %%
trans_for_weekday = df.groupby('Weekday')['Transaction'].nunique()
busiest_weekday = trans_for_weekday.idxmax()

# %%
busiest_weekday
# Out:
# 'Saturday'

# %%
trans_for_period = df.groupby('Period')['Transaction'].nunique()
busiest_period = trans_for_period.idxmax()

# %%
busiest_period
# Out:
# 'afternoon'

# %%
def profitOfHours(times, column):
    profits = {}
    for time in times: 
        profits[time] = df.loc[df[column] == time]["Item_Price"].sum()
    return profits

def getMostProfitable(column):
    times = df[column].unique()
    profits = profitOfHours(times, column)
    max_profit = max(profits.values())
    most_profitable_times = []
    for k, v in profits.items():
        if profits[k] == max_profit:
            most_profitable_times.append(k)
    return most_profitable_times

# %%
most_profitable_hour = getMostProfitable("Hour")

# %%
most_profitable_hour
# Out:
# [11]

# %%
most_profitable_weekday = getMostProfitable("Weekday")

# %%
most_profitable_weekday
# Out:
# ['Saturday']

# %%
most_profitable_period = getMostProfitable("Period")

# %%
most_profitable_period
# Out:
# ['afternoon']

# %%
def getFrequencyFromSorted(counts):
    frequent_values = []
    for count, value in zip(counts, counts.index):
        if count == counts.iloc[0]:
            frequent_values.append(value)
        else:
            break
    return frequent_values

def getMostFrequentValues(column):
    counts_descend = df[column].value_counts()
    return getFrequencyFromSorted(counts_descend)
    
def getLeastFrequentValues(column):
    counts_ascending = df[column].value_counts(ascending = True)
    return getFrequencyFromSorted(counts_ascending)

# %%
most_popular_item = getMostFrequentValues("Item")

# %%
least_popular_item = getLeastFrequentValues("Item")

# %%
items = df.groupby('Transaction')['Item'].unique()

# %%
def deleteNone(items):
    for i in items.index:
        if "NONE" in items[i]:
            index = np.argwhere(items[i] == "NONE")
            items[i] = np.delete(items[i], index)
        if len(items[i]) < 2:
            items = items.drop(i)
    return items

# %%
items = deleteNone(items)

# %%
item_choices = df['Item'].unique()
def generateCombinations(item_choices):
    none_index = np.argwhere(item_choices == "NONE")
    item_choices = np.delete(item_choices, none_index)
    combs = []
    for comb in combinations(item_choices, 2):
        combs.append(comb)
    return combs

# %%
combs = generateCombinations(item_choices)

# %%
combs
# Out:
# [('Bread', 'Scandinavian'),
#  ('Bread', 'Hot chocolate'),
#  ('Bread', 'Jam'),
#  ('Bread', 'Cookies'),
#  ('Bread', 'Muffin'),
#  ('Bread', 'Coffee'),
#  ('Bread', 'Pastry'),
#  ('Bread', 'Medialuna'),
#  ('Bread', 'Tea'),
#  ('Bread', 'Tartine'),
#  ('Bread', 'Basket'),
#  ('Bread', 'Mineral water'),
#  ('Bread', 'Farm House'),
#  ('Bread', 'Fudge'),
#  ('Bread', 'Juice'),
#  ('Bread', "Ella's Kitchen Pouches"),
#  ('Bread', 'Victorian Sponge'),
#  ('Bread', 'Frittata'),
#  ('Bread', 'Hearty & Seasonal'),
#  ('Bread', 'Soup'),
#  ('Bread', 'Pick and Mix Bowls'),
#  ('Bread', 'Smoothies'),
#  ('Bread', 'Cake'),
#  ('Bread', 'Mighty Protein'),
#  ('Bread', 'Chicken sand'),
#  ('Bread', 'Coke'),
#  ('Bread', 'My-5 Fruit Shoot'),
#  ('Bread', 'Focaccia'),
#  ('Bread', 'Sandwich'),
#  ('Bread', 'Alfajores'),
#  ('Bread', 'Eggs'),
#  ('Bread', 'Brownie'),
#  ('Bread', 'Dulce de Leche'),
#  ('Bread', 'Honey'),
#  ('Bread', 'The BART'),
#  ('Bread', 'Granola'),
#  ('Bread', 'Fairy Doors'),
#  ('Bread', 'Empanadas'),
#  ('Bread', 'Keeping It Local'),
#  ('Bread', 'Art Tray'),
#  ('Bread', 'Bowl Nic Pitt'),
#  ('Bread', 'Bread Pudding'),
#  ('Bread', 'Adjustment'),
#  ('Bread', 'Truffles'),
#  ('Bread', 'Chimichurri Oil'),
#  ('Bread', 'Bacon'),
#  ('Bread', 'Spread'),
#  ('Bread', 'Kids biscuit'),
#  ('Bread', 'Siblings'),
#  ('Bread', 'Caramel bites'),
#  ('Bread', 'Jammie Dodgers'),
#  ('Bread', 'Tiffin'),
#  ('Bread', 'Olum & polenta'),
#  ('Bread', 'Polenta'),
#  ('Bread', 'The Nomad'),
#  ('Bread', 'Hack the stack'),
#  ('Bread', 'Bakewell'),
#  ('Bread', 'Lemon and coconut'),
#  ('Bread', 'Toast'),
#  ('Bread', 'Scone'),
#  ('Bread', 'Crepes'),
#  ('Bread', 'Vegan mincepie'),
#  ('Bread', 'Bare Popcorn'),
#  ('Bread', 'Muesli'),
#  ('Bread', 'Crisps'),
#  ('Bread', 'Pintxos'),
#  ('Bread', 'Gingerbread syrup'),
#  ('Bread', 'Panatone'),
#  ('Bread', 'Brioche and salami'),
#  ('Bread', 'Afternoon with the baker'),
#  ('Bread', 'Salad'),
#  ('Bread', 'Chicken Stew'),
#  ('Bread', 'Spanish Brunch'),
#  ('Bread', 'Raspberry shortbread sandwich'),
#  ('Bread', 'Extra Salami or Feta'),
#  ('Bread', 'Duck egg'),
#  ('Bread', 'Baguette'),
#  ('Bread', "Valentine's card"),
#  ('Bread', 'Tshirt'),
#  ('Bread', 'Vegan Feast'),
#  ('Bread', 'Postcard'),
#  ('Bread', 'Nomad bag'),
#  ('Bread', 'Chocolates'),
#  ('Bread', 'Coffee granules '),
#  ('Bread', 'Drinking chocolate spoons '),
#  ('Bread', 'Christmas common'),
#  ('Bread', 'Argentina Night'),
#  ('Bread', 'Half slice Monster '),
#  ('Bread', 'Gift voucher'),
#  ('Bread', 'Cherry me Dried fruit'),
#  ('Bread', 'Mortimer'),
#  ('Bread', 'Raw bars'),
#  ('Bread', 'Tacos/Fajita'),
#  ('Scandinavian', 'Hot chocolate'),
#  ('Scandinavian', 'Jam'),
#  ('Scandinavian', 'Cookies'),
#  ('Scandinavian', 'Muffin'),
#  ('Scandinavian', 'Coffee'),
#  ('Scandinavian', 'Pastry'),
#  ('Scandinavian', 'Medialuna'),
#  ('Scandinavian', 'Tea'),
#  ('Scandinavian', 'Tartine'),
#  ('Scandinavian', 'Basket'),
#  ('Scandinavian', 'Mineral water'),
#  ('Scandinavian', 'Farm House'),
#  ('Scandinavian', 'Fudge'),
#  ('Scandinavian', 'Juice'),
#  ('Scandinavian', "Ella's Kitchen Pouches"),
#  ('Scandinavian', 'Victorian Sponge'),
#  ('Scandinavian', 'Frittata'),
#  ('Scandinavian', 'Hearty & Seasonal'),
#  ('Scandinavian', 'Soup'),
#  ('Scandinavian', 'Pick and Mix Bowls'),
#  ('Scandinavian', 'Smoothies'),
#  ('Scandinavian', 'Cake'),
#  ('Scandinavian', 'Mighty Protein'),
#  ('Scandinavian', 'Chicken sand'),
#  ('Scandinavian', 'Coke'),
#  ('Scandinavian', 'My-5 Fruit Shoot'),
#  ('Scandinavian', 'Focaccia'),
#  ('Scandinavian', 'Sandwich'),
#  ('Scandinavian', 'Alfajores'),
#  ('Scandinavian', 'Eggs'),
#  ('Scandinavian', 'Brownie'),
#  ('Scandinavian', 'Dulce de Leche'),
#  ('Scandinavian', 'Honey'),
#  ('Scandinavian', 'The BART'),
#  ('Scandinavian', 'Granola'),
#  ('Scandinavian', 'Fairy Doors'),
#  ('Scandinavian', 'Empanadas'),
#  ('Scandinavian', 'Keeping It Local'),
#  ('Scandinavian', 'Art Tray'),
#  ('Scandinavian', 'Bowl Nic Pitt'),
#  ('Scandinavian', 'Bread Pudding'),
#  ('Scandinavian', 'Adjustment'),
#  ('Scandinavian', 'Truffles'),
#  ('Scandinavian', 'Chimichurri Oil'),
#  ('Scandinavian', 'Bacon'),
#  ('Scandinavian', 'Spread'),
#  ('Scandinavian', 'Kids biscuit'),
#  ('Scandinavian', 'Siblings'),
#  ('Scandinavian', 'Caramel bites'),
#  ('Scandinavian', 'Jammie Dodgers'),
#  ('Scandinavian', 'Tiffin'),
#  ('Scandinavian', 'Olum & polenta'),
#  ('Scandinavian', 'Polenta'),
#  ('Scandinavian', 'The Nomad'),
#  ('Scandinavian', 'Hack the stack'),
#  ('Scandinavian', 'Bakewell'),
#  ('Scandinavian', 'Lemon and coconut'),
#  ('Scandinavian', 'Toast'),
#  ('Scandinavian', 'Scone'),
#  ('Scandinavian', 'Crepes'),
#  ('Scandinavian', 'Vegan mincepie'),
#  ('Scandinavian', 'Bare Popcorn'),
#  ('Scandinavian', 'Muesli'),
#  ('Scandinavian', 'Crisps'),
#  ('Scandinavian', 'Pintxos'),
#  ('Scandinavian', 'Gingerbread syrup'),
#  ('Scandinavian', 'Panatone'),
#  ('Scandinavian', 'Brioche and salami'),
#  ('Scandinavian', 'Afternoon with the baker'),
#  ('Scandinavian', 'Salad'),
#  ('Scandinavian', 'Chicken Stew'),
#  ('Scandinavian', 'Spanish Brunch'),
#  ('Scandinavian', 'Raspberry shortbread sandwich'),
#  ('Scandinavian', 'Extra Salami or Feta'),
#  ('Scandinavian', 'Duck egg'),
#  ('Scandinavian', 'Baguette'),
#  ('Scandinavian', "Valentine's card"),
#  ('Scandinavian', 'Tshirt'),
#  ('Scandinavian', 'Vegan Feast'),
#  ('Scandinavian', 'Postcard'),
#  ('Scandinavian', 'Nomad bag'),
#  ('Scandinavian', 'Chocolates'),
#  ('Scandinavian', 'Coffee granules '),
#  ('Scandinavian', 'Drinking chocolate spoons '),
#  ('Scandinavian', 'Christmas common'),
#  ('Scandinavian', 'Argentina Night'),
#  ('Scandinavian', 'Half slice Monster '),
#  ('Scandinavian', 'Gift voucher'),
#  ('Scandinavian', 'Cherry me Dried fruit'),
#  ('Scandinavian', 'Mortimer'),
#  ('Scandinavian', 'Raw bars'),
#  ('Scandinavian', 'Tacos/Fajita'),
#  ('Hot chocolate', 'Jam'),
#  ('Hot chocolate', 'Cookies'),
#  ('Hot chocolate', 'Muffin'),
#  ('Hot chocolate', 'Coffee'),
#  ('Hot chocolate', 'Pastry'),
#  ('Hot chocolate', 'Medialuna'),
#  ('Hot chocolate', 'Tea'),
#  ('Hot chocolate', 'Tartine'),
#  ('Hot chocolate', 'Basket'),
#  ('Hot chocolate', 'Mineral water'),
#  ('Hot chocolate', 'Farm House'),
#  ('Hot chocolate', 'Fudge'),
#  ('Hot chocolate', 'Juice'),
#  ('Hot chocolate', "Ella's Kitchen Pouches"),
#  ('Hot chocolate', 'Victorian Sponge'),
#  ('Hot chocolate', 'Frittata'),
#  ('Hot chocolate', 'Hearty & Seasonal'),
#  ('Hot chocolate', 'Soup'),
#  ('Hot chocolate', 'Pick and Mix Bowls'),
#  ('Hot chocolate', 'Smoothies'),
#  ('Hot chocolate', 'Cake'),
#  ('Hot chocolate', 'Mighty Protein'),
#  ('Hot chocolate', 'Chicken sand'),
#  ('Hot chocolate', 'Coke'),
#  ('Hot chocolate', 'My-5 Fruit Shoot'),
#  ('Hot chocolate', 'Focaccia'),
#  ('Hot chocolate', 'Sandwich'),
#  ('Hot chocolate', 'Alfajores'),
#  ('Hot chocolate', 'Eggs'),
#  ('Hot chocolate', 'Brownie'),
#  ('Hot chocolate', 'Dulce de Leche'),
#  ('Hot chocolate', 'Honey'),
#  ('Hot chocolate', 'The BART'),
#  ('Hot chocolate', 'Granola'),
#  ('Hot chocolate', 'Fairy Doors'),
#  ('Hot chocolate', 'Empanadas'),
#  ('Hot chocolate', 'Keeping It Local'),
#  ('Hot chocolate', 'Art Tray'),
#  ('Hot chocolate', 'Bowl Nic Pitt'),
#  ('Hot chocolate', 'Bread Pudding'),
#  ('Hot chocolate', 'Adjustment'),
#  ('Hot chocolate', 'Truffles'),
#  ('Hot chocolate', 'Chimichurri Oil'),
#  ('Hot chocolate', 'Bacon'),
#  ('Hot chocolate', 'Spread'),
#  ('Hot chocolate', 'Kids biscuit'),
#  ('Hot chocolate', 'Siblings'),
#  ('Hot chocolate', 'Caramel bites'),
#  ('Hot chocolate', 'Jammie Dodgers'),
#  ('Hot chocolate', 'Tiffin'),
#  ('Hot chocolate', 'Olum & polenta'),
#  ('Hot chocolate', 'Polenta'),
#  ('Hot chocolate', 'The Nomad'),
#  ('Hot chocolate', 'Hack the stack'),
#  ('Hot chocolate', 'Bakewell'),
#  ('Hot chocolate', 'Lemon and coconut'),
#  ('Hot chocolate', 'Toast'),
#  ('Hot chocolate', 'Scone'),
#  ('Hot chocolate', 'Crepes'),
#  ('Hot chocolate', 'Vegan mincepie'),
#  ('Hot chocolate', 'Bare Popcorn'),
#  ('Hot chocolate', 'Muesli'),
#  ('Hot chocolate', 'Crisps'),
#  ('Hot chocolate', 'Pintxos'),
#  ('Hot chocolate', 'Gingerbread syrup'),
#  ('Hot chocolate', 'Panatone'),
#  ('Hot chocolate', 'Brioche and salami'),
#  ('Hot chocolate', 'Afternoon with the baker'),
#  ('Hot chocolate', 'Salad'),
#  ('Hot chocolate', 'Chicken Stew'),
#  ('Hot chocolate', 'Spanish Brunch'),
#  ('Hot chocolate', 'Raspberry shortbread sandwich'),
#  ('Hot chocolate', 'Extra Salami or Feta'),
#  ('Hot chocolate', 'Duck egg'),
#  ('Hot chocolate', 'Baguette'),
#  ('Hot chocolate', "Valentine's card"),
#  ('Hot chocolate', 'Tshirt'),
#  ('Hot chocolate', 'Vegan Feast'),
#  ('Hot chocolate', 'Postcard'),
#  ('Hot chocolate', 'Nomad bag'),
#  ('Hot chocolate', 'Chocolates'),
#  ('Hot chocolate', 'Coffee granules '),
#  ('Hot chocolate', 'Drinking chocolate spoons '),
#  ('Hot chocolate', 'Christmas common'),
#  ('Hot chocolate', 'Argentina Night'),
#  ('Hot chocolate', 'Half slice Monster '),
#  ('Hot chocolate', 'Gift voucher'),
#  ('Hot chocolate', 'Cherry me Dried fruit'),
#  ('Hot chocolate', 'Mortimer'),
#  ('Hot chocolate', 'Raw bars'),
#  ('Hot chocolate', 'Tacos/Fajita'),
#  ('Jam', 'Cookies'),
#  ('Jam', 'Muffin'),
#  ('Jam', 'Coffee'),
#  ('Jam', 'Pastry'),
#  ('Jam', 'Medialuna'),
#  ('Jam', 'Tea'),
#  ('Jam', 'Tartine'),
#  ('Jam', 'Basket'),
#  ('Jam', 'Mineral water'),
#  ('Jam', 'Farm House'),
#  ('Jam', 'Fudge'),
#  ('Jam', 'Juice'),
#  ('Jam', "Ella's Kitchen Pouches"),
#  ('Jam', 'Victorian Sponge'),
#  ('Jam', 'Frittata'),
#  ('Jam', 'Hearty & Seasonal'),
#  ('Jam', 'Soup'),
#  ('Jam', 'Pick and Mix Bowls'),
#  ('Jam', 'Smoothies'),
#  ('Jam', 'Cake'),
#  ('Jam', 'Mighty Protein'),
#  ('Jam', 'Chicken sand'),
#  ('Jam', 'Coke'),
#  ('Jam', 'My-5 Fruit Shoot'),
#  ('Jam', 'Focaccia'),
#  ('Jam', 'Sandwich'),
#  ('Jam', 'Alfajores'),
#  ('Jam', 'Eggs'),
#  ('Jam', 'Brownie'),
#  ('Jam', 'Dulce de Leche'),
#  ('Jam', 'Honey'),
#  ('Jam', 'The BART'),
#  ('Jam', 'Granola'),
#  ('Jam', 'Fairy Doors'),
#  ('Jam', 'Empanadas'),
#  ('Jam', 'Keeping It Local'),
#  ('Jam', 'Art Tray'),
#  ('Jam', 'Bowl Nic Pitt'),
#  ('Jam', 'Bread Pudding'),
#  ('Jam', 'Adjustment'),
#  ('Jam', 'Truffles'),
#  ('Jam', 'Chimichurri Oil'),
#  ('Jam', 'Bacon'),
#  ('Jam', 'Spread'),
#  ('Jam', 'Kids biscuit'),
#  ('Jam', 'Siblings'),
#  ('Jam', 'Caramel bites'),
#  ('Jam', 'Jammie Dodgers'),
#  ('Jam', 'Tiffin'),
#  ('Jam', 'Olum & polenta'),
#  ('Jam', 'Polenta'),
#  ('Jam', 'The Nomad'),
#  ('Jam', 'Hack the stack'),
#  ('Jam', 'Bakewell'),
#  ('Jam', 'Lemon and coconut'),
#  ('Jam', 'Toast'),
#  ('Jam', 'Scone'),
#  ('Jam', 'Crepes'),
#  ('Jam', 'Vegan mincepie'),
#  ('Jam', 'Bare Popcorn'),
#  ('Jam', 'Muesli'),
#  ('Jam', 'Crisps'),
#  ('Jam', 'Pintxos'),
#  ('Jam', 'Gingerbread syrup'),
#  ('Jam', 'Panatone'),
#  ('Jam', 'Brioche and salami'),
#  ('Jam', 'Afternoon with the baker'),
#  ('Jam', 'Salad'),
#  ('Jam', 'Chicken Stew'),
#  ('Jam', 'Spanish Brunch'),
#  ('Jam', 'Raspberry shortbread sandwich'),
#  ('Jam', 'Extra Salami or Feta'),
#  ('Jam', 'Duck egg'),
#  ('Jam', 'Baguette'),
#  ('Jam', "Valentine's card"),
#  ('Jam', 'Tshirt'),
#  ('Jam', 'Vegan Feast'),
#  ('Jam', 'Postcard'),
#  ('Jam', 'Nomad bag'),
#  ('Jam', 'Chocolates'),
#  ('Jam', 'Coffee granules '),
#  ('Jam', 'Drinking chocolate spoons '),
#  ('Jam', 'Christmas common'),
#  ('Jam', 'Argentina Night'),
#  ('Jam', 'Half slice Monster '),
#  ('Jam', 'Gift voucher'),
#  ('Jam', 'Cherry me Dried fruit'),
#  ('Jam', 'Mortimer'),
#  ('Jam', 'Raw bars'),
#  ('Jam', 'Tacos/Fajita'),
#  ('Cookies', 'Muffin'),
#  ('Cookies', 'Coffee'),
#  ('Cookies', 'Pastry'),
#  ('Cookies', 'Medialuna'),
#  ('Cookies', 'Tea'),
#  ('Cookies', 'Tartine'),
#  ('Cookies', 'Basket'),
#  ('Cookies', 'Mineral water'),
#  ('Cookies', 'Farm House'),
#  ('Cookies', 'Fudge'),
#  ('Cookies', 'Juice'),
#  ('Cookies', "Ella's Kitchen Pouches"),
#  ('Cookies', 'Victorian Sponge'),
#  ('Cookies', 'Frittata'),
#  ('Cookies', 'Hearty & Seasonal'),
#  ('Cookies', 'Soup'),
#  ('Cookies', 'Pick and Mix Bowls'),
#  ('Cookies', 'Smoothies'),
#  ('Cookies', 'Cake'),
#  ('Cookies', 'Mighty Protein'),
#  ('Cookies', 'Chicken sand'),
#  ('Cookies', 'Coke'),
#  ('Cookies', 'My-5 Fruit Shoot'),
#  ('Cookies', 'Focaccia'),
#  ('Cookies', 'Sandwich'),
#  ('Cookies', 'Alfajores'),
#  ('Cookies', 'Eggs'),
#  ('Cookies', 'Brownie'),
#  ('Cookies', 'Dulce de Leche'),
#  ('Cookies', 'Honey'),
#  ('Cookies', 'The BART'),
#  ('Cookies', 'Granola'),
#  ('Cookies', 'Fairy Doors'),
#  ('Cookies', 'Empanadas'),
#  ('Cookies', 'Keeping It Local'),
#  ('Cookies', 'Art Tray'),
#  ('Cookies', 'Bowl Nic Pitt'),
#  ('Cookies', 'Bread Pudding'),
#  ('Cookies', 'Adjustment'),
#  ('Cookies', 'Truffles'),
#  ('Cookies', 'Chimichurri Oil'),
#  ('Cookies', 'Bacon'),
#  ('Cookies', 'Spread'),
#  ('Cookies', 'Kids biscuit'),
#  ('Cookies', 'Siblings'),
#  ('Cookies', 'Caramel bites'),
#  ('Cookies', 'Jammie Dodgers'),
#  ('Cookies', 'Tiffin'),
#  ('Cookies', 'Olum & polenta'),
#  ('Cookies', 'Polenta'),
#  ('Cookies', 'The Nomad'),
#  ('Cookies', 'Hack the stack'),
#  ('Cookies', 'Bakewell'),
#  ('Cookies', 'Lemon and coconut'),
#  ('Cookies', 'Toast'),
#  ('Cookies', 'Scone'),
#  ('Cookies', 'Crepes'),
#  ('Cookies', 'Vegan mincepie'),
#  ('Cookies', 'Bare Popcorn'),
#  ('Cookies', 'Muesli'),
#  ('Cookies', 'Crisps'),
#  ('Cookies', 'Pintxos'),
#  ('Cookies', 'Gingerbread syrup'),
#  ('Cookies', 'Panatone'),
#  ('Cookies', 'Brioche and salami'),
#  ('Cookies', 'Afternoon with the baker'),
#  ('Cookies', 'Salad'),
#  ('Cookies', 'Chicken Stew'),
#  ('Cookies', 'Spanish Brunch'),
#  ('Cookies', 'Raspberry shortbread sandwich'),
#  ('Cookies', 'Extra Salami or Feta'),
#  ('Cookies', 'Duck egg'),
#  ('Cookies', 'Baguette'),
#  ('Cookies', "Valentine's card"),
#  ('Cookies', 'Tshirt'),
#  ('Cookies', 'Vegan Feast'),
#  ('Cookies', 'Postcard'),
#  ('Cookies', 'Nomad bag'),
#  ('Cookies', 'Chocolates'),
#  ('Cookies', 'Coffee granules '),
#  ('Cookies', 'Drinking chocolate spoons '),
#  ('Cookies', 'Christmas common'),
#  ('Cookies', 'Argentina Night'),
#  ('Cookies', 'Half slice Monster '),
#  ('Cookies', 'Gift voucher'),
#  ('Cookies', 'Cherry me Dried fruit'),
#  ('Cookies', 'Mortimer'),
#  ('Cookies', 'Raw bars'),
#  ('Cookies', 'Tacos/Fajita'),
#  ('Muffin', 'Coffee'),
#  ('Muffin', 'Pastry'),
#  ('Muffin', 'Medialuna'),
#  ('Muffin', 'Tea'),
#  ('Muffin', 'Tartine'),
#  ('Muffin', 'Basket'),
#  ('Muffin', 'Mineral water'),
#  ('Muffin', 'Farm House'),
#  ('Muffin', 'Fudge'),
#  ('Muffin', 'Juice'),
#  ('Muffin', "Ella's Kitchen Pouches"),
#  ('Muffin', 'Victorian Sponge'),
#  ('Muffin', 'Frittata'),
#  ('Muffin', 'Hearty & Seasonal'),
#  ('Muffin', 'Soup'),
#  ('Muffin', 'Pick and Mix Bowls'),
#  ('Muffin', 'Smoothies'),
#  ('Muffin', 'Cake'),
#  ('Muffin', 'Mighty Protein'),
#  ('Muffin', 'Chicken sand'),
#  ('Muffin', 'Coke'),
#  ('Muffin', 'My-5 Fruit Shoot'),
#  ('Muffin', 'Focaccia'),
#  ('Muffin', 'Sandwich'),
#  ('Muffin', 'Alfajores'),
#  ('Muffin', 'Eggs'),
#  ('Muffin', 'Brownie'),
#  ('Muffin', 'Dulce de Leche'),
#  ('Muffin', 'Honey'),
#  ('Muffin', 'The BART'),
#  ('Muffin', 'Granola'),
#  ('Muffin', 'Fairy Doors'),
#  ('Muffin', 'Empanadas'),
#  ('Muffin', 'Keeping It Local'),
#  ('Muffin', 'Art Tray'),
#  ('Muffin', 'Bowl Nic Pitt'),
#  ('Muffin', 'Bread Pudding'),
#  ('Muffin', 'Adjustment'),
#  ('Muffin', 'Truffles'),
#  ('Muffin', 'Chimichurri Oil'),
#  ('Muffin', 'Bacon'),
#  ('Muffin', 'Spread'),
#  ('Muffin', 'Kids biscuit'),
#  ('Muffin', 'Siblings'),
#  ('Muffin', 'Caramel bites'),
#  ('Muffin', 'Jammie Dodgers'),
#  ('Muffin', 'Tiffin'),
#  ('Muffin', 'Olum & polenta'),
#  ('Muffin', 'Polenta'),
#  ('Muffin', 'The Nomad'),
#  ('Muffin', 'Hack the stack'),
#  ('Muffin', 'Bakewell'),
#  ('Muffin', 'Lemon and coconut'),
#  ('Muffin', 'Toast'),
#  ('Muffin', 'Scone'),
#  ('Muffin', 'Crepes'),
#  ('Muffin', 'Vegan mincepie'),
#  ('Muffin', 'Bare Popcorn'),
#  ('Muffin', 'Muesli'),
#  ('Muffin', 'Crisps'),
#  ('Muffin', 'Pintxos'),
#  ('Muffin', 'Gingerbread syrup'),
#  ('Muffin', 'Panatone'),
#  ('Muffin', 'Brioche and salami'),
#  ('Muffin', 'Afternoon with the baker'),
#  ('Muffin', 'Salad'),
#  ('Muffin', 'Chicken Stew'),
#  ('Muffin', 'Spanish Brunch'),
#  ('Muffin', 'Raspberry shortbread sandwich'),
#  ('Muffin', 'Extra Salami or Feta'),
#  ('Muffin', 'Duck egg'),
#  ('Muffin', 'Baguette'),
#  ('Muffin', "Valentine's card"),
#  ('Muffin', 'Tshirt'),
#  ('Muffin', 'Vegan Feast'),
#  ('Muffin', 'Postcard'),
#  ('Muffin', 'Nomad bag'),
#  ('Muffin', 'Chocolates'),
#  ('Muffin', 'Coffee granules '),
#  ('Muffin', 'Drinking chocolate spoons '),
#  ('Muffin', 'Christmas common'),
#  ('Muffin', 'Argentina Night'),
#  ('Muffin', 'Half slice Monster '),
#  ('Muffin', 'Gift voucher'),
#  ('Muffin', 'Cherry me Dried fruit'),
#  ('Muffin', 'Mortimer'),
#  ('Muffin', 'Raw bars'),
#  ('Muffin', 'Tacos/Fajita'),
#  ('Coffee', 'Pastry'),
#  ('Coffee', 'Medialuna'),
#  ('Coffee', 'Tea'),
#  ('Coffee', 'Tartine'),
#  ('Coffee', 'Basket'),
#  ('Coffee', 'Mineral water'),
#  ('Coffee', 'Farm House'),
#  ('Coffee', 'Fudge'),
#  ('Coffee', 'Juice'),
#  ('Coffee', "Ella's Kitchen Pouches"),
#  ('Coffee', 'Victorian Sponge'),
#  ('Coffee', 'Frittata'),
#  ('Coffee', 'Hearty & Seasonal'),
#  ('Coffee', 'Soup'),
#  ('Coffee', 'Pick and Mix Bowls'),
#  ('Coffee', 'Smoothies'),
#  ('Coffee', 'Cake'),
#  ('Coffee', 'Mighty Protein'),
#  ('Coffee', 'Chicken sand'),
#  ('Coffee', 'Coke'),
#  ('Coffee', 'My-5 Fruit Shoot'),
#  ('Coffee', 'Focaccia'),
#  ('Coffee', 'Sandwich'),
#  ('Coffee', 'Alfajores'),
#  ('Coffee', 'Eggs'),
#  ('Coffee', 'Brownie'),
#  ('Coffee', 'Dulce de Leche'),
#  ('Coffee', 'Honey'),
#  ('Coffee', 'The BART'),
#  ('Coffee', 'Granola'),
#  ('Coffee', 'Fairy Doors'),
#  ('Coffee', 'Empanadas'),
#  ('Coffee', 'Keeping It Local'),
#  ('Coffee', 'Art Tray'),
#  ('Coffee', 'Bowl Nic Pitt'),
#  ('Coffee', 'Bread Pudding'),
#  ('Coffee', 'Adjustment'),
#  ('Coffee', 'Truffles'),
#  ('Coffee', 'Chimichurri Oil'),
#  ('Coffee', 'Bacon'),
#  ('Coffee', 'Spread'),
#  ('Coffee', 'Kids biscuit'),
#  ('Coffee', 'Siblings'),
#  ('Coffee', 'Caramel bites'),
#  ('Coffee', 'Jammie Dodgers'),
#  ('Coffee', 'Tiffin'),
#  ('Coffee', 'Olum & polenta'),
#  ('Coffee', 'Polenta'),
#  ('Coffee', 'The Nomad'),
#  ('Coffee', 'Hack the stack'),
#  ('Coffee', 'Bakewell'),
#  ('Coffee', 'Lemon and coconut'),
#  ('Coffee', 'Toast'),
#  ('Coffee', 'Scone'),
#  ('Coffee', 'Crepes'),
#  ('Coffee', 'Vegan mincepie'),
#  ('Coffee', 'Bare Popcorn'),
#  ('Coffee', 'Muesli'),
#  ('Coffee', 'Crisps'),
#  ('Coffee', 'Pintxos'),
#  ('Coffee', 'Gingerbread syrup'),
#  ('Coffee', 'Panatone'),
#  ('Coffee', 'Brioche and salami'),
#  ('Coffee', 'Afternoon with the baker'),
#  ('Coffee', 'Salad'),
#  ('Coffee', 'Chicken Stew'),
#  ('Coffee', 'Spanish Brunch'),
#  ('Coffee', 'Raspberry shortbread sandwich'),
#  ('Coffee', 'Extra Salami or Feta'),
#  ('Coffee', 'Duck egg'),
#  ('Coffee', 'Baguette'),
#  ('Coffee', "Valentine's card"),
#  ('Coffee', 'Tshirt'),
#  ('Coffee', 'Vegan Feast'),
#  ('Coffee', 'Postcard'),
#  ('Coffee', 'Nomad bag'),
#  ('Coffee', 'Chocolates'),
#  ('Coffee', 'Coffee granules '),
#  ('Coffee', 'Drinking chocolate spoons '),
#  ('Coffee', 'Christmas common'),
#  ('Coffee', 'Argentina Night'),
#  ('Coffee', 'Half slice Monster '),
#  ('Coffee', 'Gift voucher'),
#  ('Coffee', 'Cherry me Dried fruit'),
#  ('Coffee', 'Mortimer'),
#  ('Coffee', 'Raw bars'),
#  ('Coffee', 'Tacos/Fajita'),
#  ('Pastry', 'Medialuna'),
#  ('Pastry', 'Tea'),
#  ('Pastry', 'Tartine'),
#  ('Pastry', 'Basket'),
#  ('Pastry', 'Mineral water'),
#  ('Pastry', 'Farm House'),
#  ('Pastry', 'Fudge'),
#  ('Pastry', 'Juice'),
#  ('Pastry', "Ella's Kitchen Pouches"),
#  ('Pastry', 'Victorian Sponge'),
#  ('Pastry', 'Frittata'),
#  ('Pastry', 'Hearty & Seasonal'),
#  ('Pastry', 'Soup'),
#  ('Pastry', 'Pick and Mix Bowls'),
#  ('Pastry', 'Smoothies'),
#  ('Pastry', 'Cake'),
#  ('Pastry', 'Mighty Protein'),
#  ('Pastry', 'Chicken sand'),
#  ('Pastry', 'Coke'),
#  ('Pastry', 'My-5 Fruit Shoot'),
#  ('Pastry', 'Focaccia'),
#  ('Pastry', 'Sandwich'),
#  ('Pastry', 'Alfajores'),
#  ('Pastry', 'Eggs'),
#  ('Pastry', 'Brownie'),
#  ('Pastry', 'Dulce de Leche'),
#  ('Pastry', 'Honey'),
#  ('Pastry', 'The BART'),
#  ('Pastry', 'Granola'),
#  ('Pastry', 'Fairy Doors'),
#  ('Pastry', 'Empanadas'),
#  ('Pastry', 'Keeping It Local'),
#  ('Pastry', 'Art Tray'),
#  ('Pastry', 'Bowl Nic Pitt'),
#  ('Pastry', 'Bread Pudding'),
#  ('Pastry', 'Adjustment'),
#  ('Pastry', 'Truffles'),
#  ('Pastry', 'Chimichurri Oil'),
#  ('Pastry', 'Bacon'),
#  ('Pastry', 'Spread'),
#  ('Pastry', 'Kids biscuit'),
#  ('Pastry', 'Siblings'),
#  ('Pastry', 'Caramel bites'),
#  ('Pastry', 'Jammie Dodgers'),
#  ('Pastry', 'Tiffin'),
#  ('Pastry', 'Olum & polenta'),
#  ('Pastry', 'Polenta'),
#  ('Pastry', 'The Nomad'),
#  ('Pastry', 'Hack the stack'),
#  ('Pastry', 'Bakewell'),
#  ('Pastry', 'Lemon and coconut'),
#  ('Pastry', 'Toast'),
#  ('Pastry', 'Scone'),
#  ('Pastry', 'Crepes'),
#  ('Pastry', 'Vegan mincepie'),
#  ('Pastry', 'Bare Popcorn'),
#  ('Pastry', 'Muesli'),
#  ('Pastry', 'Crisps'),
#  ('Pastry', 'Pintxos'),
#  ('Pastry', 'Gingerbread syrup'),
#  ('Pastry', 'Panatone'),
#  ('Pastry', 'Brioche and salami'),
#  ('Pastry', 'Afternoon with the baker'),
#  ('Pastry', 'Salad'),
#  ('Pastry', 'Chicken Stew'),
#  ('Pastry', 'Spanish Brunch'),
#  ('Pastry', 'Raspberry shortbread sandwich'),
#  ('Pastry', 'Extra Salami or Feta'),
#  ('Pastry', 'Duck egg'),
#  ('Pastry', 'Baguette'),
#  ('Pastry', "Valentine's card"),
#  ('Pastry', 'Tshirt'),
#  ('Pastry', 'Vegan Feast'),
#  ('Pastry', 'Postcard'),
#  ('Pastry', 'Nomad bag'),
#  ('Pastry', 'Chocolates'),
#  ('Pastry', 'Coffee granules '),
#  ('Pastry', 'Drinking chocolate spoons '),
#  ('Pastry', 'Christmas common'),
#  ('Pastry', 'Argentina Night'),
#  ('Pastry', 'Half slice Monster '),
#  ('Pastry', 'Gift voucher'),
#  ('Pastry', 'Cherry me Dried fruit'),
#  ('Pastry', 'Mortimer'),
#  ('Pastry', 'Raw bars'),
#  ('Pastry', 'Tacos/Fajita'),
#  ('Medialuna', 'Tea'),
#  ('Medialuna', 'Tartine'),
#  ('Medialuna', 'Basket'),
#  ('Medialuna', 'Mineral water'),
#  ('Medialuna', 'Farm House'),
#  ('Medialuna', 'Fudge'),
#  ('Medialuna', 'Juice'),
#  ('Medialuna', "Ella's Kitchen Pouches"),
#  ('Medialuna', 'Victorian Sponge'),
#  ('Medialuna', 'Frittata'),
#  ('Medialuna', 'Hearty & Seasonal'),
#  ('Medialuna', 'Soup'),
#  ('Medialuna', 'Pick and Mix Bowls'),
#  ('Medialuna', 'Smoothies'),
#  ('Medialuna', 'Cake'),
#  ('Medialuna', 'Mighty Protein'),
#  ('Medialuna', 'Chicken sand'),
#  ('Medialuna', 'Coke'),
#  ('Medialuna', 'My-5 Fruit Shoot'),
#  ('Medialuna', 'Focaccia'),
#  ('Medialuna', 'Sandwich'),
#  ('Medialuna', 'Alfajores'),
#  ('Medialuna', 'Eggs'),
#  ('Medialuna', 'Brownie'),
#  ('Medialuna', 'Dulce de Leche'),
#  ('Medialuna', 'Honey'),
#  ('Medialuna', 'The BART'),
#  ('Medialuna', 'Granola'),
#  ('Medialuna', 'Fairy Doors'),
#  ('Medialuna', 'Empanadas'),
#  ('Medialuna', 'Keeping It Local'),
#  ('Medialuna', 'Art Tray'),
#  ('Medialuna', 'Bowl Nic Pitt'),
#  ('Medialuna', 'Bread Pudding'),
#  ('Medialuna', 'Adjustment'),
#  ('Medialuna', 'Truffles'),
#  ('Medialuna', 'Chimichurri Oil'),
#  ('Medialuna', 'Bacon'),
#  ('Medialuna', 'Spread'),
#  ('Medialuna', 'Kids biscuit'),
#  ('Medialuna', 'Siblings'),
#  ('Medialuna', 'Caramel bites'),
#  ('Medialuna', 'Jammie Dodgers'),
#  ('Medialuna', 'Tiffin'),
#  ('Medialuna', 'Olum & polenta'),
#  ('Medialuna', 'Polenta'),
#  ('Medialuna', 'The Nomad'),
#  ('Medialuna', 'Hack the stack'),
#  ('Medialuna', 'Bakewell'),
#  ('Medialuna', 'Lemon and coconut'),
#  ('Medialuna', 'Toast'),
#  ('Medialuna', 'Scone'),
#  ('Medialuna', 'Crepes'),
#  ('Medialuna', 'Vegan mincepie'),
#  ('Medialuna', 'Bare Popcorn'),
#  ('Medialuna', 'Muesli'),
#  ('Medialuna', 'Crisps'),
#  ('Medialuna', 'Pintxos'),
#  ('Medialuna', 'Gingerbread syrup'),
#  ('Medialuna', 'Panatone'),
#  ('Medialuna', 'Brioche and salami'),
#  ('Medialuna', 'Afternoon with the baker'),
#  ('Medialuna', 'Salad'),
#  ('Medialuna', 'Chicken Stew'),
#  ('Medialuna', 'Spanish Brunch'),
#  ('Medialuna', 'Raspberry shortbread sandwich'),
#  ('Medialuna', 'Extra Salami or Feta'),
#  ('Medialuna', 'Duck egg'),
#  ('Medialuna', 'Baguette'),
#  ('Medialuna', "Valentine's card"),
#  ('Medialuna', 'Tshirt'),
#  ('Medialuna', 'Vegan Feast'),
#  ('Medialuna', 'Postcard'),
#  ('Medialuna', 'Nomad bag'),
#  ('Medialuna', 'Chocolates'),
#  ('Medialuna', 'Coffee granules '),
#  ('Medialuna', 'Drinking chocolate spoons '),
#  ('Medialuna', 'Christmas common'),
#  ('Medialuna', 'Argentina Night'),
#  ('Medialuna', 'Half slice Monster '),
#  ('Medialuna', 'Gift voucher'),
#  ('Medialuna', 'Cherry me Dried fruit'),
#  ('Medialuna', 'Mortimer'),
#  ('Medialuna', 'Raw bars'),
#  ('Medialuna', 'Tacos/Fajita'),
#  ('Tea', 'Tartine'),
#  ('Tea', 'Basket'),
#  ('Tea', 'Mineral water'),
#  ('Tea', 'Farm House'),
#  ('Tea', 'Fudge'),
#  ('Tea', 'Juice'),
#  ('Tea', "Ella's Kitchen Pouches"),
#  ('Tea', 'Victorian Sponge'),
#  ('Tea', 'Frittata'),
#  ('Tea', 'Hearty & Seasonal'),
#  ('Tea', 'Soup'),
#  ('Tea', 'Pick and Mix Bowls'),
#  ('Tea', 'Smoothies'),
#  ('Tea', 'Cake'),
#  ('Tea', 'Mighty Protein'),
#  ('Tea', 'Chicken sand'),
#  ('Tea', 'Coke'),
#  ('Tea', 'My-5 Fruit Shoot'),
#  ('Tea', 'Focaccia'),
#  ('Tea', 'Sandwich'),
#  ('Tea', 'Alfajores'),
#  ('Tea', 'Eggs'),
#  ('Tea', 'Brownie'),
#  ('Tea', 'Dulce de Leche'),
#  ('Tea', 'Honey'),
#  ('Tea', 'The BART'),
#  ('Tea', 'Granola'),
#  ('Tea', 'Fairy Doors'),
#  ('Tea', 'Empanadas'),
#  ('Tea', 'Keeping It Local'),
#  ('Tea', 'Art Tray'),
#  ('Tea', 'Bowl Nic Pitt'),
#  ('Tea', 'Bread Pudding'),
#  ('Tea', 'Adjustment'),
#  ('Tea', 'Truffles'),
#  ('Tea', 'Chimichurri Oil'),
#  ('Tea', 'Bacon'),
#  ('Tea', 'Spread'),
#  ('Tea', 'Kids biscuit'),
#  ('Tea', 'Siblings'),
#  ('Tea', 'Caramel bites'),
#  ('Tea', 'Jammie Dodgers'),
#  ('Tea', 'Tiffin'),
#  ('Tea', 'Olum & polenta'),
#  ('Tea', 'Polenta'),
#  ('Tea', 'The Nomad'),
#  ('Tea', 'Hack the stack'),
#  ('Tea', 'Bakewell'),
#  ('Tea', 'Lemon and coconut'),
#  ('Tea', 'Toast'),
#  ('Tea', 'Scone'),
#  ('Tea', 'Crepes'),
#  ('Tea', 'Vegan mincepie'),
#  ('Tea', 'Bare Popcorn'),
#  ('Tea', 'Muesli'),
#  ('Tea', 'Crisps'),
#  ('Tea', 'Pintxos'),
#  ('Tea', 'Gingerbread syrup'),
#  ('Tea', 'Panatone'),
#  ('Tea', 'Brioche and salami'),
#  ('Tea', 'Afternoon with the baker'),
#  ('Tea', 'Salad'),
#  ('Tea', 'Chicken Stew'),
#  ('Tea', 'Spanish Brunch'),
#  ('Tea', 'Raspberry shortbread sandwich'),
#  ('Tea', 'Extra Salami or Feta'),
#  ('Tea', 'Duck egg'),
#  ('Tea', 'Baguette'),
#  ('Tea', "Valentine's card"),
#  ('Tea', 'Tshirt'),
#  ('Tea', 'Vegan Feast'),
#  ('Tea', 'Postcard'),
#  ('Tea', 'Nomad bag'),
#  ('Tea', 'Chocolates'),
#  ('Tea', 'Coffee granules '),
#  ('Tea', 'Drinking chocolate spoons '),
#  ('Tea', 'Christmas common'),
#  ('Tea', 'Argentina Night'),
#  ('Tea', 'Half slice Monster '),
#  ('Tea', 'Gift voucher'),
#  ('Tea', 'Cherry me Dried fruit'),
#  ('Tea', 'Mortimer'),
#  ('Tea', 'Raw bars'),
#  ('Tea', 'Tacos/Fajita'),
#  ('Tartine', 'Basket'),
#  ('Tartine', 'Mineral water'),
#  ('Tartine', 'Farm House'),
#  ('Tartine', 'Fudge'),
#  ('Tartine', 'Juice'),
#  ('Tartine', "Ella's Kitchen Pouches"),
#  ('Tartine', 'Victorian Sponge'),
#  ('Tartine', 'Frittata'),
#  ('Tartine', 'Hearty & Seasonal'),
#  ('Tartine', 'Soup'),
#  ('Tartine', 'Pick and Mix Bowls'),
#  ('Tartine', 'Smoothies'),
#  ('Tartine', 'Cake'),
#  ('Tartine', 'Mighty Protein'),
#  ('Tartine', 'Chicken sand'),
#  ('Tartine', 'Coke'),
#  ('Tartine', 'My-5 Fruit Shoot'),
#  ('Tartine', 'Focaccia'),
#  ('Tartine', 'Sandwich'),
#  ('Tartine', 'Alfajores'),
#  ('Tartine', 'Eggs'),
#  ('Tartine', 'Brownie'),
#  ('Tartine', 'Dulce de Leche'),
#  ('Tartine', 'Honey'),
#  ('Tartine', 'The BART'),
#  ('Tartine', 'Granola'),
#  ('Tartine', 'Fairy Doors'),
#  ('Tartine', 'Empanadas'),
#  ('Tartine', 'Keeping It Local'),
#  ('Tartine', 'Art Tray'),
#  ('Tartine', 'Bowl Nic Pitt'),
#  ('Tartine', 'Bread Pudding'),
#  ('Tartine', 'Adjustment'),
#  ('Tartine', 'Truffles'),
#  ('Tartine', 'Chimichurri Oil'),
#  ('Tartine', 'Bacon'),
#  ('Tartine', 'Spread'),
#  ('Tartine', 'Kids biscuit'),
#  ('Tartine', 'Siblings'),
#  ('Tartine', 'Caramel bites'),
#  ('Tartine', 'Jammie Dodgers'),
#  ('Tartine', 'Tiffin'),
#  ('Tartine', 'Olum & polenta'),
#  ('Tartine', 'Polenta'),
#  ('Tartine', 'The Nomad'),
#  ('Tartine', 'Hack the stack'),
#  ('Tartine', 'Bakewell'),
#  ('Tartine', 'Lemon and coconut'),
#  ('Tartine', 'Toast'),
#  ('Tartine', 'Scone'),
#  ('Tartine', 'Crepes'),
#  ('Tartine', 'Vegan mincepie'),
#  ('Tartine', 'Bare Popcorn'),
#  ('Tartine', 'Muesli'),
#  ('Tartine', 'Crisps'),
#  ('Tartine', 'Pintxos'),
#  ('Tartine', 'Gingerbread syrup'),
#  ('Tartine', 'Panatone'),
#  ('Tartine', 'Brioche and salami'),
#  ('Tartine', 'Afternoon with the baker'),
#  ('Tartine', 'Salad'),
#  ('Tartine', 'Chicken Stew'),
#  ('Tartine', 'Spanish Brunch'),
#  ('Tartine', 'Raspberry shortbread sandwich'),
#  ('Tartine', 'Extra Salami or Feta'),
#  ('Tartine', 'Duck egg'),
#  ('Tartine', 'Baguette'),
#  ('Tartine', "Valentine's card"),
#  ('Tartine', 'Tshirt'),
#  ('Tartine', 'Vegan Feast'),
#  ('Tartine', 'Postcard'),
#  ('Tartine', 'Nomad bag'),
#  ('Tartine', 'Chocolates'),
#  ('Tartine', 'Coffee granules '),
#  ('Tartine', 'Drinking chocolate spoons '),
#  ('Tartine', 'Christmas common'),
#  ('Tartine', 'Argentina Night'),
#  ('Tartine', 'Half slice Monster '),
#  ('Tartine', 'Gift voucher'),
#  ('Tartine', 'Cherry me Dried fruit'),
#  ('Tartine', 'Mortimer'),
#  ('Tartine', 'Raw bars'),
#  ('Tartine', 'Tacos/Fajita'),
#  ('Basket', 'Mineral water'),
#  ('Basket', 'Farm House'),
#  ('Basket', 'Fudge'),
#  ('Basket', 'Juice'),
#  ('Basket', "Ella's Kitchen Pouches"),
#  ('Basket', 'Victorian Sponge'),
#  ('Basket', 'Frittata'),
#  ('Basket', 'Hearty & Seasonal'),
#  ('Basket', 'Soup'),
#  ('Basket', 'Pick and Mix Bowls'),
#  ('Basket', 'Smoothies'),
#  ('Basket', 'Cake'),
#  ('Basket', 'Mighty Protein'),
#  ('Basket', 'Chicken sand'),
#  ('Basket', 'Coke'),
#  ('Basket', 'My-5 Fruit Shoot'),
#  ('Basket', 'Focaccia'),
#  ('Basket', 'Sandwich'),
#  ('Basket', 'Alfajores'),
#  ('Basket', 'Eggs'),
#  ('Basket', 'Brownie'),
#  ('Basket', 'Dulce de Leche'),
#  ('Basket', 'Honey'),
#  ('Basket', 'The BART'),
#  ('Basket', 'Granola'),
#  ('Basket', 'Fairy Doors'),
#  ('Basket', 'Empanadas'),
#  ('Basket', 'Keeping It Local'),
#  ('Basket', 'Art Tray'),
#  ('Basket', 'Bowl Nic Pitt'),
#  ('Basket', 'Bread Pudding'),
#  ('Basket', 'Adjustment'),
#  ...]

# %%
def generateCombsDict(combs, items):
    combs_dict ={}
    for k in combs:
        combs_dict[k] = 0
    for comb in combs:
        for item in items:
            if set(comb).issubset(item):
                combs_dict[comb] += 1
    return combs_dict

# %%
combs_dict = generateCombsDict(combs, items)

# %%
combs_dict
# Out:
# {('Bread', 'Scandinavian'): 62,
#  ('Bread', 'Hot chocolate'): 127,
#  ('Bread', 'Jam'): 48,
#  ('Bread', 'Cookies'): 137,
#  ('Bread', 'Muffin'): 77,
#  ('Bread', 'Coffee'): 852,
#  ('Bread', 'Pastry'): 276,
#  ('Bread', 'Medialuna'): 160,
#  ('Bread', 'Tea'): 266,
#  ('Bread', 'Tartine'): 8,
#  ('Bread', 'Basket'): 2,
#  ('Bread', 'Mineral water'): 30,
#  ('Bread', 'Farm House'): 47,
#  ('Bread', 'Fudge'): 31,
#  ('Bread', 'Juice'): 70,
#  ('Bread', "Ella's Kitchen Pouches"): 5,
#  ('Bread', 'Victorian Sponge'): 2,
#  ('Bread', 'Frittata'): 25,
#  ('Bread', 'Hearty & Seasonal'): 25,
#  ('Bread', 'Soup'): 62,
#  ('Bread', 'Pick and Mix Bowls'): 1,
#  ('Bread', 'Smoothies'): 23,
#  ('Bread', 'Cake'): 221,
#  ('Bread', 'Mighty Protein'): 0,
#  ('Bread', 'Chicken sand'): 0,
#  ('Bread', 'Coke'): 18,
#  ('Bread', 'My-5 Fruit Shoot'): 5,
#  ('Bread', 'Focaccia'): 19,
#  ('Bread', 'Sandwich'): 161,
#  ('Bread', 'Alfajores'): 98,
#  ('Bread', 'Eggs'): 14,
#  ('Bread', 'Brownie'): 102,
#  ('Bread', 'Dulce de Leche'): 2,
#  ('Bread', 'Honey'): 2,
#  ('Bread', 'The BART'): 1,
#  ('Bread', 'Granola'): 9,
#  ('Bread', 'Fairy Doors'): 0,
#  ('Bread', 'Empanadas'): 3,
#  ('Bread', 'Keeping It Local'): 21,
#  ('Bread', 'Art Tray'): 6,
#  ('Bread', 'Bowl Nic Pitt'): 0,
#  ('Bread', 'Bread Pudding'): 0,
#  ('Bread', 'Adjustment'): 0,
#  ('Bread', 'Truffles'): 47,
#  ('Bread', 'Chimichurri Oil'): 0,
#  ('Bread', 'Bacon'): 0,
#  ('Bread', 'Spread'): 1,
#  ('Bread', 'Kids biscuit'): 2,
#  ('Bread', 'Siblings'): 0,
#  ('Bread', 'Caramel bites'): 1,
#  ('Bread', 'Jammie Dodgers'): 44,
#  ('Bread', 'Tiffin'): 46,
#  ('Bread', 'Olum & polenta'): 1,
#  ('Bread', 'Polenta'): 0,
#  ('Bread', 'The Nomad'): 16,
#  ('Bread', 'Hack the stack'): 0,
#  ('Bread', 'Bakewell'): 11,
#  ('Bread', 'Lemon and coconut'): 3,
#  ('Bread', 'Toast'): 74,
#  ('Bread', 'Scone'): 86,
#  ('Bread', 'Crepes'): 1,
#  ('Bread', 'Vegan mincepie'): 13,
#  ('Bread', 'Bare Popcorn'): 0,
#  ('Bread', 'Muesli'): 3,
#  ('Bread', 'Crisps'): 4,
#  ('Bread', 'Pintxos'): 0,
#  ('Bread', 'Gingerbread syrup'): 1,
#  ('Bread', 'Panatone'): 1,
#  ('Bread', 'Brioche and salami'): 2,
#  ('Bread', 'Afternoon with the baker'): 3,
#  ('Bread', 'Salad'): 19,
#  ('Bread', 'Chicken Stew'): 26,
#  ('Bread', 'Spanish Brunch'): 45,
#  ('Bread', 'Raspberry shortbread sandwich'): 1,
#  ('Bread', 'Extra Salami or Feta'): 10,
#  ('Bread', 'Duck egg'): 2,
#  ('Bread', 'Baguette'): 26,
#  ('Bread', "Valentine's card"): 0,
#  ('Bread', 'Tshirt'): 1,
#  ('Bread', 'Vegan Feast'): 1,
#  ('Bread', 'Postcard'): 0,
#  ('Bread', 'Nomad bag'): 6,
#  ('Bread', 'Chocolates'): 2,
#  ('Bread', 'Coffee granules '): 0,
#  ('Bread', 'Drinking chocolate spoons '): 5,
#  ('Bread', 'Christmas common'): 3,
#  ('Bread', 'Argentina Night'): 1,
#  ('Bread', 'Half slice Monster '): 0,
#  ('Bread', 'Gift voucher'): 1,
#  ('Bread', 'Cherry me Dried fruit'): 0,
#  ('Bread', 'Mortimer'): 0,
#  ('Bread', 'Raw bars'): 0,
#  ('Bread', 'Tacos/Fajita'): 3,
#  ('Scandinavian', 'Hot chocolate'): 5,
#  ('Scandinavian', 'Jam'): 4,
#  ('Scandinavian', 'Cookies'): 8,
#  ('Scandinavian', 'Muffin'): 13,
#  ('Scandinavian', 'Coffee'): 46,
#  ('Scandinavian', 'Pastry'): 14,
#  ('Scandinavian', 'Medialuna'): 12,
#  ('Scandinavian', 'Tea'): 8,
#  ('Scandinavian', 'Tartine'): 1,
#  ('Scandinavian', 'Basket'): 0,
#  ('Scandinavian', 'Mineral water'): 3,
#  ('Scandinavian', 'Farm House'): 16,
#  ('Scandinavian', 'Fudge'): 4,
#  ('Scandinavian', 'Juice'): 1,
#  ('Scandinavian', "Ella's Kitchen Pouches"): 0,
#  ('Scandinavian', 'Victorian Sponge'): 1,
#  ('Scandinavian', 'Frittata'): 3,
#  ('Scandinavian', 'Hearty & Seasonal'): 1,
#  ('Scandinavian', 'Soup'): 3,
#  ('Scandinavian', 'Pick and Mix Bowls'): 0,
#  ('Scandinavian', 'Smoothies'): 0,
#  ('Scandinavian', 'Cake'): 14,
#  ('Scandinavian', 'Mighty Protein'): 0,
#  ('Scandinavian', 'Chicken sand'): 1,
#  ('Scandinavian', 'Coke'): 0,
#  ('Scandinavian', 'My-5 Fruit Shoot'): 1,
#  ('Scandinavian', 'Focaccia'): 4,
#  ('Scandinavian', 'Sandwich'): 3,
#  ('Scandinavian', 'Alfajores'): 14,
#  ('Scandinavian', 'Eggs'): 2,
#  ('Scandinavian', 'Brownie'): 5,
#  ('Scandinavian', 'Dulce de Leche'): 1,
#  ('Scandinavian', 'Honey'): 1,
#  ('Scandinavian', 'The BART'): 0,
#  ('Scandinavian', 'Granola'): 2,
#  ('Scandinavian', 'Fairy Doors'): 1,
#  ('Scandinavian', 'Empanadas'): 1,
#  ('Scandinavian', 'Keeping It Local'): 1,
#  ('Scandinavian', 'Art Tray'): 0,
#  ('Scandinavian', 'Bowl Nic Pitt'): 0,
#  ('Scandinavian', 'Bread Pudding'): 0,
#  ('Scandinavian', 'Adjustment'): 0,
#  ('Scandinavian', 'Truffles'): 3,
#  ('Scandinavian', 'Chimichurri Oil'): 1,
#  ('Scandinavian', 'Bacon'): 0,
#  ('Scandinavian', 'Spread'): 0,
#  ('Scandinavian', 'Kids biscuit'): 0,
#  ('Scandinavian', 'Siblings'): 0,
#  ('Scandinavian', 'Caramel bites'): 0,
#  ('Scandinavian', 'Jammie Dodgers'): 1,
#  ('Scandinavian', 'Tiffin'): 0,
#  ('Scandinavian', 'Olum & polenta'): 0,
#  ('Scandinavian', 'Polenta'): 0,
#  ('Scandinavian', 'The Nomad'): 0,
#  ('Scandinavian', 'Hack the stack'): 0,
#  ('Scandinavian', 'Bakewell'): 0,
#  ('Scandinavian', 'Lemon and coconut'): 0,
#  ('Scandinavian', 'Toast'): 4,
#  ('Scandinavian', 'Scone'): 4,
#  ('Scandinavian', 'Crepes'): 0,
#  ('Scandinavian', 'Vegan mincepie'): 1,
#  ('Scandinavian', 'Bare Popcorn'): 0,
#  ('Scandinavian', 'Muesli'): 0,
#  ('Scandinavian', 'Crisps'): 0,
#  ('Scandinavian', 'Pintxos'): 0,
#  ('Scandinavian', 'Gingerbread syrup'): 0,
#  ('Scandinavian', 'Panatone'): 0,
#  ('Scandinavian', 'Brioche and salami'): 0,
#  ('Scandinavian', 'Afternoon with the baker'): 1,
#  ('Scandinavian', 'Salad'): 3,
#  ('Scandinavian', 'Chicken Stew'): 0,
#  ('Scandinavian', 'Spanish Brunch'): 0,
#  ('Scandinavian', 'Raspberry shortbread sandwich'): 0,
#  ('Scandinavian', 'Extra Salami or Feta'): 2,
#  ('Scandinavian', 'Duck egg'): 0,
#  ('Scandinavian', 'Baguette'): 9,
#  ('Scandinavian', "Valentine's card"): 0,
#  ('Scandinavian', 'Tshirt'): 0,
#  ('Scandinavian', 'Vegan Feast'): 0,
#  ('Scandinavian', 'Postcard'): 0,
#  ('Scandinavian', 'Nomad bag'): 1,
#  ('Scandinavian', 'Chocolates'): 0,
#  ('Scandinavian', 'Coffee granules '): 0,
#  ('Scandinavian', 'Drinking chocolate spoons '): 0,
#  ('Scandinavian', 'Christmas common'): 1,
#  ('Scandinavian', 'Argentina Night'): 0,
#  ('Scandinavian', 'Half slice Monster '): 0,
#  ('Scandinavian', 'Gift voucher'): 0,
#  ('Scandinavian', 'Cherry me Dried fruit'): 0,
#  ('Scandinavian', 'Mortimer'): 0,
#  ('Scandinavian', 'Raw bars'): 0,
#  ('Scandinavian', 'Tacos/Fajita'): 0,
#  ('Hot chocolate', 'Jam'): 4,
#  ('Hot chocolate', 'Cookies'): 57,
#  ('Hot chocolate', 'Muffin'): 34,
#  ('Hot chocolate', 'Coffee'): 280,
#  ('Hot chocolate', 'Pastry'): 54,
#  ('Hot chocolate', 'Medialuna'): 45,
#  ('Hot chocolate', 'Tea'): 76,
#  ('Hot chocolate', 'Tartine'): 2,
#  ('Hot chocolate', 'Basket'): 2,
#  ('Hot chocolate', 'Mineral water'): 9,
#  ('Hot chocolate', 'Farm House'): 8,
#  ('Hot chocolate', 'Fudge'): 5,
#  ('Hot chocolate', 'Juice'): 21,
#  ('Hot chocolate', "Ella's Kitchen Pouches"): 0,
#  ('Hot chocolate', 'Victorian Sponge'): 1,
#  ('Hot chocolate', 'Frittata'): 0,
#  ('Hot chocolate', 'Hearty & Seasonal'): 7,
#  ('Hot chocolate', 'Soup'): 8,
#  ('Hot chocolate', 'Pick and Mix Bowls'): 1,
#  ('Hot chocolate', 'Smoothies'): 8,
#  ('Hot chocolate', 'Cake'): 108,
#  ('Hot chocolate', 'Mighty Protein'): 0,
#  ('Hot chocolate', 'Chicken sand'): 0,
#  ('Hot chocolate', 'Coke'): 6,
#  ('Hot chocolate', 'My-5 Fruit Shoot'): 3,
#  ('Hot chocolate', 'Focaccia'): 0,
#  ('Hot chocolate', 'Sandwich'): 42,
#  ('Hot chocolate', 'Alfajores'): 34,
#  ('Hot chocolate', 'Eggs'): 2,
#  ('Hot chocolate', 'Brownie'): 39,
#  ('Hot chocolate', 'Dulce de Leche'): 0,
#  ('Hot chocolate', 'Honey'): 0,
#  ('Hot chocolate', 'The BART'): 0,
#  ('Hot chocolate', 'Granola'): 2,
#  ('Hot chocolate', 'Fairy Doors'): 0,
#  ('Hot chocolate', 'Empanadas'): 0,
#  ('Hot chocolate', 'Keeping It Local'): 2,
#  ('Hot chocolate', 'Art Tray'): 6,
#  ('Hot chocolate', 'Bowl Nic Pitt'): 0,
#  ('Hot chocolate', 'Bread Pudding'): 0,
#  ('Hot chocolate', 'Adjustment'): 0,
#  ('Hot chocolate', 'Truffles'): 8,
#  ('Hot chocolate', 'Chimichurri Oil'): 0,
#  ('Hot chocolate', 'Bacon'): 0,
#  ('Hot chocolate', 'Spread'): 0,
#  ('Hot chocolate', 'Kids biscuit'): 0,
#  ('Hot chocolate', 'Siblings'): 0,
#  ('Hot chocolate', 'Caramel bites'): 0,
#  ('Hot chocolate', 'Jammie Dodgers'): 14,
#  ('Hot chocolate', 'Tiffin'): 13,
#  ('Hot chocolate', 'Olum & polenta'): 0,
#  ('Hot chocolate', 'Polenta'): 0,
#  ('Hot chocolate', 'The Nomad'): 3,
#  ('Hot chocolate', 'Hack the stack'): 0,
#  ('Hot chocolate', 'Bakewell'): 3,
#  ('Hot chocolate', 'Lemon and coconut'): 1,
#  ('Hot chocolate', 'Toast'): 29,
#  ('Hot chocolate', 'Scone'): 28,
#  ('Hot chocolate', 'Crepes'): 0,
#  ('Hot chocolate', 'Vegan mincepie'): 9,
#  ('Hot chocolate', 'Bare Popcorn'): 1,
#  ('Hot chocolate', 'Muesli'): 0,
#  ('Hot chocolate', 'Crisps'): 3,
#  ('Hot chocolate', 'Pintxos'): 0,
#  ('Hot chocolate', 'Gingerbread syrup'): 0,
#  ('Hot chocolate', 'Panatone'): 0,
#  ('Hot chocolate', 'Brioche and salami'): 0,
#  ('Hot chocolate', 'Afternoon with the baker'): 1,
#  ('Hot chocolate', 'Salad'): 2,
#  ('Hot chocolate', 'Chicken Stew'): 3,
#  ('Hot chocolate', 'Spanish Brunch'): 8,
#  ('Hot chocolate', 'Raspberry shortbread sandwich'): 0,
#  ('Hot chocolate', 'Extra Salami or Feta'): 2,
#  ('Hot chocolate', 'Duck egg'): 1,
#  ('Hot chocolate', 'Baguette'): 4,
#  ('Hot chocolate', "Valentine's card"): 0,
#  ('Hot chocolate', 'Tshirt'): 1,
#  ('Hot chocolate', 'Vegan Feast'): 1,
#  ('Hot chocolate', 'Postcard'): 0,
#  ('Hot chocolate', 'Nomad bag'): 0,
#  ('Hot chocolate', 'Chocolates'): 4,
#  ('Hot chocolate', 'Coffee granules '): 0,
#  ('Hot chocolate', 'Drinking chocolate spoons '): 2,
#  ('Hot chocolate', 'Christmas common'): 1,
#  ('Hot chocolate', 'Argentina Night'): 0,
#  ('Hot chocolate', 'Half slice Monster '): 1,
#  ('Hot chocolate', 'Gift voucher'): 0,
#  ('Hot chocolate', 'Cherry me Dried fruit'): 1,
#  ('Hot chocolate', 'Mortimer'): 0,
#  ('Hot chocolate', 'Raw bars'): 0,
#  ('Hot chocolate', 'Tacos/Fajita'): 0,
#  ('Jam', 'Cookies'): 5,
#  ('Jam', 'Muffin'): 4,
#  ('Jam', 'Coffee'): 39,
#  ('Jam', 'Pastry'): 12,
#  ('Jam', 'Medialuna'): 5,
#  ('Jam', 'Tea'): 12,
#  ('Jam', 'Tartine'): 4,
#  ('Jam', 'Basket'): 0,
#  ('Jam', 'Mineral water'): 1,
#  ('Jam', 'Farm House'): 6,
#  ('Jam', 'Fudge'): 24,
#  ('Jam', 'Juice'): 5,
#  ('Jam', "Ella's Kitchen Pouches"): 2,
#  ('Jam', 'Victorian Sponge'): 0,
#  ('Jam', 'Frittata'): 2,
#  ('Jam', 'Hearty & Seasonal'): 0,
#  ('Jam', 'Soup'): 5,
#  ('Jam', 'Pick and Mix Bowls'): 2,
#  ('Jam', 'Smoothies'): 1,
#  ('Jam', 'Cake'): 6,
#  ('Jam', 'Mighty Protein'): 0,
#  ('Jam', 'Chicken sand'): 0,
#  ('Jam', 'Coke'): 0,
#  ('Jam', 'My-5 Fruit Shoot'): 0,
#  ('Jam', 'Focaccia'): 1,
#  ('Jam', 'Sandwich'): 3,
#  ('Jam', 'Alfajores'): 2,
#  ('Jam', 'Eggs'): 0,
#  ('Jam', 'Brownie'): 3,
#  ('Jam', 'Dulce de Leche'): 0,
#  ('Jam', 'Honey'): 0,
#  ('Jam', 'The BART'): 0,
#  ('Jam', 'Granola'): 0,
#  ('Jam', 'Fairy Doors'): 0,
#  ('Jam', 'Empanadas'): 0,
#  ('Jam', 'Keeping It Local'): 2,
#  ('Jam', 'Art Tray'): 0,
#  ('Jam', 'Bowl Nic Pitt'): 0,
#  ('Jam', 'Bread Pudding'): 1,
#  ('Jam', 'Adjustment'): 0,
#  ('Jam', 'Truffles'): 1,
#  ('Jam', 'Chimichurri Oil'): 0,
#  ('Jam', 'Bacon'): 0,
#  ('Jam', 'Spread'): 1,
#  ('Jam', 'Kids biscuit'): 0,
#  ('Jam', 'Siblings'): 0,
#  ('Jam', 'Caramel bites'): 0,
#  ('Jam', 'Jammie Dodgers'): 0,
#  ('Jam', 'Tiffin'): 0,
#  ('Jam', 'Olum & polenta'): 0,
#  ('Jam', 'Polenta'): 0,
#  ('Jam', 'The Nomad'): 1,
#  ('Jam', 'Hack the stack'): 0,
#  ('Jam', 'Bakewell'): 0,
#  ('Jam', 'Lemon and coconut'): 0,
#  ('Jam', 'Toast'): 1,
#  ('Jam', 'Scone'): 2,
#  ('Jam', 'Crepes'): 0,
#  ('Jam', 'Vegan mincepie'): 0,
#  ('Jam', 'Bare Popcorn'): 0,
#  ('Jam', 'Muesli'): 0,
#  ('Jam', 'Crisps'): 0,
#  ('Jam', 'Pintxos'): 0,
#  ('Jam', 'Gingerbread syrup'): 1,
#  ('Jam', 'Panatone'): 0,
#  ('Jam', 'Brioche and salami'): 0,
#  ('Jam', 'Afternoon with the baker'): 0,
#  ('Jam', 'Salad'): 2,
#  ('Jam', 'Chicken Stew'): 0,
#  ('Jam', 'Spanish Brunch'): 3,
#  ('Jam', 'Raspberry shortbread sandwich'): 0,
#  ('Jam', 'Extra Salami or Feta'): 1,
#  ('Jam', 'Duck egg'): 1,
#  ('Jam', 'Baguette'): 0,
#  ('Jam', "Valentine's card"): 0,
#  ('Jam', 'Tshirt'): 0,
#  ('Jam', 'Vegan Feast'): 0,
#  ('Jam', 'Postcard'): 0,
#  ('Jam', 'Nomad bag'): 0,
#  ('Jam', 'Chocolates'): 0,
#  ('Jam', 'Coffee granules '): 0,
#  ('Jam', 'Drinking chocolate spoons '): 0,
#  ('Jam', 'Christmas common'): 2,
#  ('Jam', 'Argentina Night'): 0,
#  ('Jam', 'Half slice Monster '): 0,
#  ('Jam', 'Gift voucher'): 0,
#  ('Jam', 'Cherry me Dried fruit'): 0,
#  ('Jam', 'Mortimer'): 0,
#  ('Jam', 'Raw bars'): 0,
#  ('Jam', 'Tacos/Fajita'): 0,
#  ('Cookies', 'Muffin'): 16,
#  ('Cookies', 'Coffee'): 267,
#  ('Cookies', 'Pastry'): 28,
#  ('Cookies', 'Medialuna'): 24,
#  ('Cookies', 'Tea'): 93,
#  ('Cookies', 'Tartine'): 2,
#  ('Cookies', 'Basket'): 0,
#  ('Cookies', 'Mineral water'): 13,
#  ('Cookies', 'Farm House'): 12,
#  ('Cookies', 'Fudge'): 3,
#  ('Cookies', 'Juice'): 58,
#  ('Cookies', "Ella's Kitchen Pouches"): 3,
#  ('Cookies', 'Victorian Sponge'): 0,
#  ('Cookies', 'Frittata'): 4,
#  ('Cookies', 'Hearty & Seasonal'): 3,
#  ('Cookies', 'Soup'): 12,
#  ('Cookies', 'Pick and Mix Bowls'): 2,
#  ('Cookies', 'Smoothies'): 5,
#  ('Cookies', 'Cake'): 69,
#  ('Cookies', 'Mighty Protein'): 0,
#  ('Cookies', 'Chicken sand'): 0,
#  ('Cookies', 'Coke'): 6,
#  ('Cookies', 'My-5 Fruit Shoot'): 4,
#  ('Cookies', 'Focaccia'): 2,
#  ('Cookies', 'Sandwich'): 27,
#  ('Cookies', 'Alfajores'): 23,
#  ('Cookies', 'Eggs'): 1,
#  ('Cookies', 'Brownie'): 24,
#  ('Cookies', 'Dulce de Leche'): 0,
#  ('Cookies', 'Honey'): 1,
#  ('Cookies', 'The BART'): 0,
#  ('Cookies', 'Granola'): 1,
#  ('Cookies', 'Fairy Doors'): 0,
#  ('Cookies', 'Empanadas'): 0,
#  ('Cookies', 'Keeping It Local'): 3,
#  ('Cookies', 'Art Tray'): 4,
#  ('Cookies', 'Bowl Nic Pitt'): 0,
#  ('Cookies', 'Bread Pudding'): 0,
#  ('Cookies', 'Adjustment'): 0,
#  ('Cookies', 'Truffles'): 7,
#  ('Cookies', 'Chimichurri Oil'): 0,
#  ('Cookies', 'Bacon'): 0,
#  ('Cookies', 'Spread'): 0,
#  ('Cookies', 'Kids biscuit'): 0,
#  ('Cookies', 'Siblings'): 0,
#  ('Cookies', 'Caramel bites'): 0,
#  ('Cookies', 'Jammie Dodgers'): 10,
#  ('Cookies', 'Tiffin'): 12,
#  ('Cookies', 'Olum & polenta'): 0,
#  ('Cookies', 'Polenta'): 0,
#  ('Cookies', 'The Nomad'): 3,
#  ('Cookies', 'Hack the stack'): 0,
#  ('Cookies', 'Bakewell'): 4,
#  ('Cookies', 'Lemon and coconut'): 0,
#  ('Cookies', 'Toast'): 21,
#  ('Cookies', 'Scone'): 19,
#  ('Cookies', 'Crepes'): 0,
#  ('Cookies', 'Vegan mincepie'): 3,
#  ('Cookies', 'Bare Popcorn'): 2,
#  ('Cookies', 'Muesli'): 1,
#  ('Cookies', 'Crisps'): 2,
#  ('Cookies', 'Pintxos'): 0,
#  ('Cookies', 'Gingerbread syrup'): 0,
#  ('Cookies', 'Panatone'): 1,
#  ('Cookies', 'Brioche and salami'): 0,
#  ('Cookies', 'Afternoon with the baker'): 1,
#  ('Cookies', 'Salad'): 4,
#  ('Cookies', 'Chicken Stew'): 4,
#  ('Cookies', 'Spanish Brunch'): 7,
#  ('Cookies', 'Raspberry shortbread sandwich'): 0,
#  ('Cookies', 'Extra Salami or Feta'): 3,
#  ('Cookies', 'Duck egg'): 2,
#  ('Cookies', 'Baguette'): 7,
#  ('Cookies', "Valentine's card"): 0,
#  ('Cookies', 'Tshirt'): 0,
#  ('Cookies', 'Vegan Feast'): 2,
#  ('Cookies', 'Postcard'): 0,
#  ('Cookies', 'Nomad bag'): 0,
#  ('Cookies', 'Chocolates'): 2,
#  ('Cookies', 'Coffee granules '): 0,
#  ('Cookies', 'Drinking chocolate spoons '): 0,
#  ('Cookies', 'Christmas common'): 0,
#  ('Cookies', 'Argentina Night'): 0,
#  ('Cookies', 'Half slice Monster '): 1,
#  ('Cookies', 'Gift voucher'): 0,
#  ('Cookies', 'Cherry me Dried fruit'): 0,
#  ('Cookies', 'Mortimer'): 0,
#  ('Cookies', 'Raw bars'): 0,
#  ('Cookies', 'Tacos/Fajita'): 0,
#  ('Muffin', 'Coffee'): 178,
#  ('Muffin', 'Pastry'): 24,
#  ('Muffin', 'Medialuna'): 19,
#  ('Muffin', 'Tea'): 62,
#  ('Muffin', 'Tartine'): 2,
#  ('Muffin', 'Basket'): 0,
#  ('Muffin', 'Mineral water'): 5,
#  ('Muffin', 'Farm House'): 7,
#  ('Muffin', 'Fudge'): 4,
#  ('Muffin', 'Juice'): 26,
#  ('Muffin', "Ella's Kitchen Pouches"): 2,
#  ('Muffin', 'Victorian Sponge'): 0,
#  ('Muffin', 'Frittata'): 6,
#  ('Muffin', 'Hearty & Seasonal'): 6,
#  ('Muffin', 'Soup'): 12,
#  ('Muffin', 'Pick and Mix Bowls'): 0,
#  ('Muffin', 'Smoothies'): 8,
#  ('Muffin', 'Cake'): 46,
#  ('Muffin', 'Mighty Protein'): 0,
#  ('Muffin', 'Chicken sand'): 0,
#  ('Muffin', 'Coke'): 5,
#  ('Muffin', 'My-5 Fruit Shoot'): 3,
#  ('Muffin', 'Focaccia'): 1,
#  ('Muffin', 'Sandwich'): 20,
#  ('Muffin', 'Alfajores'): 16,
#  ('Muffin', 'Eggs'): 0,
#  ('Muffin', 'Brownie'): 17,
#  ('Muffin', 'Dulce de Leche'): 0,
#  ('Muffin', 'Honey'): 0,
#  ('Muffin', 'The BART'): 0,
#  ('Muffin', 'Granola'): 1,
#  ('Muffin', 'Fairy Doors'): 0,
#  ('Muffin', 'Empanadas'): 1,
#  ('Muffin', 'Keeping It Local'): 1,
#  ('Muffin', 'Art Tray'): 3,
#  ('Muffin', 'Bowl Nic Pitt'): 1,
#  ('Muffin', 'Bread Pudding'): 0,
#  ('Muffin', 'Adjustment'): 0,
#  ('Muffin', 'Truffles'): 5,
#  ('Muffin', 'Chimichurri Oil'): 0,
#  ('Muffin', 'Bacon'): 0,
#  ('Muffin', 'Spread'): 0,
#  ('Muffin', 'Kids biscuit'): 3,
#  ('Muffin', 'Siblings'): 0,
#  ('Muffin', 'Caramel bites'): 0,
#  ('Muffin', 'Jammie Dodgers'): 9,
#  ('Muffin', 'Tiffin'): 6,
#  ('Muffin', 'Olum & polenta'): 0,
#  ('Muffin', 'Polenta'): 0,
#  ('Muffin', 'The Nomad'): 2,
#  ('Muffin', 'Hack the stack'): 0,
#  ('Muffin', 'Bakewell'): 1,
#  ('Muffin', 'Lemon and coconut'): 0,
#  ('Muffin', 'Toast'): 6,
#  ('Muffin', 'Scone'): 7,
#  ('Muffin', 'Crepes'): 0,
#  ('Muffin', 'Vegan mincepie'): 0,
#  ('Muffin', 'Bare Popcorn'): 1,
#  ('Muffin', 'Muesli'): 0,
#  ('Muffin', 'Crisps'): 0,
#  ('Muffin', 'Pintxos'): 0,
#  ('Muffin', 'Gingerbread syrup'): 1,
#  ('Muffin', 'Panatone'): 1,
#  ('Muffin', 'Brioche and salami'): 0,
#  ('Muffin', 'Afternoon with the baker'): 0,
#  ('Muffin', 'Salad'): 2,
#  ('Muffin', 'Chicken Stew'): 1,
#  ('Muffin', 'Spanish Brunch'): 3,
#  ('Muffin', 'Raspberry shortbread sandwich'): 0,
#  ('Muffin', 'Extra Salami or Feta'): 1,
#  ('Muffin', 'Duck egg'): 0,
#  ('Muffin', 'Baguette'): 3,
#  ('Muffin', "Valentine's card"): 0,
#  ('Muffin', 'Tshirt'): 0,
#  ('Muffin', 'Vegan Feast'): 1,
#  ('Muffin', 'Postcard'): 0,
#  ('Muffin', 'Nomad bag'): 0,
#  ('Muffin', 'Chocolates'): 0,
#  ('Muffin', 'Coffee granules '): 0,
#  ('Muffin', 'Drinking chocolate spoons '): 1,
#  ('Muffin', 'Christmas common'): 0,
#  ('Muffin', 'Argentina Night'): 0,
#  ('Muffin', 'Half slice Monster '): 0,
#  ('Muffin', 'Gift voucher'): 0,
#  ('Muffin', 'Cherry me Dried fruit'): 0,
#  ('Muffin', 'Mortimer'): 0,
#  ('Muffin', 'Raw bars'): 0,
#  ('Muffin', 'Tacos/Fajita'): 1,
#  ('Coffee', 'Pastry'): 450,
#  ('Coffee', 'Medialuna'): 333,
#  ('Coffee', 'Tea'): 472,
#  ('Coffee', 'Tartine'): 29,
#  ('Coffee', 'Basket'): 4,
#  ('Coffee', 'Mineral water'): 53,
#  ('Coffee', 'Farm House'): 63,
#  ('Coffee', 'Fudge'): 31,
#  ('Coffee', 'Juice'): 195,
#  ('Coffee', "Ella's Kitchen Pouches"): 6,
#  ('Coffee', 'Victorian Sponge'): 0,
#  ('Coffee', 'Frittata'): 43,
#  ('Coffee', 'Hearty & Seasonal'): 54,
#  ('Coffee', 'Soup'): 150,
#  ('Coffee', 'Pick and Mix Bowls'): 6,
#  ('Coffee', 'Smoothies'): 38,
#  ('Coffee', 'Cake'): 518,
#  ('Coffee', 'Mighty Protein'): 9,
#  ('Coffee', 'Chicken sand'): 1,
#  ('Coffee', 'Coke'): 61,
#  ('Coffee', 'My-5 Fruit Shoot'): 7,
#  ('Coffee', 'Focaccia'): 9,
#  ('Coffee', 'Sandwich'): 362,
#  ('Coffee', 'Alfajores'): 186,
#  ('Coffee', 'Eggs'): 7,
#  ('Coffee', 'Brownie'): 186,
#  ('Coffee', 'Dulce de Leche'): 3,
#  ('Coffee', 'Honey'): 2,
#  ('Coffee', 'The BART'): 0,
#  ('Coffee', 'Granola'): 17,
#  ('Coffee', 'Fairy Doors'): 0,
#  ('Coffee', 'Empanadas'): 4,
#  ('Coffee', 'Keeping It Local'): 51,
#  ('Coffee', 'Art Tray'): 26,
#  ('Coffee', 'Bowl Nic Pitt'): 2,
#  ('Coffee', 'Bread Pudding'): 4,
#  ('Coffee', 'Adjustment'): 0,
#  ('Coffee', 'Truffles'): 71,
#  ('Coffee', 'Chimichurri Oil'): 0,
#  ('Coffee', 'Bacon'): 1,
#  ('Coffee', 'Spread'): 0,
#  ('Coffee', 'Kids biscuit'): 6,
#  ('Coffee', 'Siblings'): 0,
#  ('Coffee', 'Caramel bites'): 2,
#  ('Coffee', 'Jammie Dodgers'): 63,
#  ('Coffee', 'Tiffin'): 80,
#  ('Coffee', 'Olum & polenta'): 0,
#  ('Coffee', 'Polenta'): 0,
#  ('Coffee', 'The Nomad'): 31,
#  ('Coffee', 'Hack the stack'): 1,
#  ('Coffee', 'Bakewell'): 29,
#  ('Coffee', 'Lemon and coconut'): 4,
#  ('Coffee', 'Toast'): 224,
#  ('Coffee', 'Scone'): 171,
#  ('Coffee', 'Crepes'): 2,
#  ('Coffee', 'Vegan mincepie'): 30,
#  ('Coffee', 'Bare Popcorn'): 3,
#  ('Coffee', 'Muesli'): 3,
#  ('Coffee', 'Crisps'): 8,
#  ('Coffee', 'Pintxos'): 0,
#  ('Coffee', 'Gingerbread syrup'): 2,
#  ('Coffee', 'Panatone'): 1,
#  ('Coffee', 'Brioche and salami'): 2,
#  ('Coffee', 'Afternoon with the baker'): 4,
#  ('Coffee', 'Salad'): 62,
#  ('Coffee', 'Chicken Stew'): 49,
#  ('Coffee', 'Spanish Brunch'): 103,
#  ('Coffee', 'Raspberry shortbread sandwich'): 1,
#  ('Coffee', 'Extra Salami or Feta'): 31,
#  ('Coffee', 'Duck egg'): 7,
#  ('Coffee', 'Baguette'): 28,
#  ('Coffee', "Valentine's card"): 0,
#  ('Coffee', 'Tshirt'): 1,
#  ('Coffee', 'Vegan Feast'): 2,
#  ('Coffee', 'Postcard'): 1,
#  ('Coffee', 'Nomad bag'): 4,
#  ('Coffee', 'Chocolates'): 5,
#  ('Coffee', 'Coffee granules '): 2,
#  ('Coffee', 'Drinking chocolate spoons '): 5,
#  ('Coffee', 'Christmas common'): 0,
#  ('Coffee', 'Argentina Night'): 0,
#  ('Coffee', 'Half slice Monster '): 2,
#  ('Coffee', 'Gift voucher'): 0,
#  ('Coffee', 'Cherry me Dried fruit'): 2,
#  ('Coffee', 'Mortimer'): 0,
#  ('Coffee', 'Raw bars'): 0,
#  ('Coffee', 'Tacos/Fajita'): 5,
#  ('Pastry', 'Medialuna'): 87,
#  ('Pastry', 'Tea'): 91,
#  ('Pastry', 'Tartine'): 3,
#  ('Pastry', 'Basket'): 0,
#  ('Pastry', 'Mineral water'): 2,
#  ('Pastry', 'Farm House'): 26,
#  ('Pastry', 'Fudge'): 5,
#  ('Pastry', 'Juice'): 22,
#  ('Pastry', "Ella's Kitchen Pouches"): 2,
#  ('Pastry', 'Victorian Sponge'): 0,
#  ('Pastry', 'Frittata'): 5,
#  ('Pastry', 'Hearty & Seasonal'): 3,
#  ('Pastry', 'Soup'): 9,
#  ('Pastry', 'Pick and Mix Bowls'): 0,
#  ('Pastry', 'Smoothies'): 4,
#  ('Pastry', 'Cake'): 49,
#  ('Pastry', 'Mighty Protein'): 0,
#  ('Pastry', 'Chicken sand'): 0,
#  ('Pastry', 'Coke'): 8,
#  ('Pastry', 'My-5 Fruit Shoot'): 1,
#  ('Pastry', 'Focaccia'): 4,
#  ('Pastry', 'Sandwich'): 11,
#  ('Pastry', 'Alfajores'): 31,
#  ('Pastry', 'Eggs'): 3,
#  ('Pastry', 'Brownie'): 23,
#  ('Pastry', 'Dulce de Leche'): 2,
#  ('Pastry', 'Honey'): 1,
#  ('Pastry', 'The BART'): 0,
#  ('Pastry', 'Granola'): 4,
#  ('Pastry', 'Fairy Doors'): 0,
#  ('Pastry', 'Empanadas'): 0,
#  ('Pastry', 'Keeping It Local'): 3,
#  ('Pastry', 'Art Tray'): 2,
#  ('Pastry', 'Bowl Nic Pitt'): 0,
#  ('Pastry', 'Bread Pudding'): 0,
#  ('Pastry', 'Adjustment'): 0,
#  ('Pastry', 'Truffles'): 16,
#  ('Pastry', 'Chimichurri Oil'): 0,
#  ('Pastry', 'Bacon'): 0,
#  ('Pastry', 'Spread'): 0,
#  ('Pastry', 'Kids biscuit'): 0,
#  ('Pastry', 'Siblings'): 0,
#  ('Pastry', 'Caramel bites'): 0,
#  ('Pastry', 'Jammie Dodgers'): 4,
#  ('Pastry', 'Tiffin'): 7,
#  ('Pastry', 'Olum & polenta'): 0,
#  ('Pastry', 'Polenta'): 0,
#  ('Pastry', 'The Nomad'): 5,
#  ('Pastry', 'Hack the stack'): 0,
#  ('Pastry', 'Bakewell'): 3,
#  ('Pastry', 'Lemon and coconut'): 0,
#  ('Pastry', 'Toast'): 15,
#  ('Pastry', 'Scone'): 23,
#  ('Pastry', 'Crepes'): 0,
#  ('Pastry', 'Vegan mincepie'): 3,
#  ('Pastry', 'Bare Popcorn'): 0,
#  ('Pastry', 'Muesli'): 0,
#  ('Pastry', 'Crisps'): 0,
#  ('Pastry', 'Pintxos'): 0,
#  ('Pastry', 'Gingerbread syrup'): 1,
#  ('Pastry', 'Panatone'): 0,
#  ('Pastry', 'Brioche and salami'): 0,
#  ('Pastry', 'Afternoon with the baker'): 0,
#  ('Pastry', 'Salad'): 2,
#  ('Pastry', 'Chicken Stew'): 5,
#  ('Pastry', 'Spanish Brunch'): 4,
#  ('Pastry', 'Raspberry shortbread sandwich'): 0,
#  ('Pastry', 'Extra Salami or Feta'): 0,
#  ('Pastry', 'Duck egg'): 0,
#  ('Pastry', 'Baguette'): 8,
#  ('Pastry', "Valentine's card"): 0,
#  ('Pastry', 'Tshirt'): 0,
#  ('Pastry', 'Vegan Feast'): 1,
#  ('Pastry', 'Postcard'): 0,
#  ('Pastry', 'Nomad bag'): 1,
#  ('Pastry', 'Chocolates'): 1,
#  ('Pastry', 'Coffee granules '): 0,
#  ('Pastry', 'Drinking chocolate spoons '): 1,
#  ('Pastry', 'Christmas common'): 0,
#  ('Pastry', 'Argentina Night'): 0,
#  ('Pastry', 'Half slice Monster '): 0,
#  ('Pastry', 'Gift voucher'): 0,
#  ('Pastry', 'Cherry me Dried fruit'): 0,
#  ('Pastry', 'Mortimer'): 0,
#  ('Pastry', 'Raw bars'): 0,
#  ('Pastry', 'Tacos/Fajita'): 0,
#  ('Medialuna', 'Tea'): 77,
#  ('Medialuna', 'Tartine'): 2,
#  ('Medialuna', 'Basket'): 0,
#  ('Medialuna', 'Mineral water'): 3,
#  ('Medialuna', 'Farm House'): 22,
#  ('Medialuna', 'Fudge'): 7,
#  ('Medialuna', 'Juice'): 20,
#  ('Medialuna', "Ella's Kitchen Pouches"): 3,
#  ('Medialuna', 'Victorian Sponge'): 0,
#  ('Medialuna', 'Frittata'): 3,
#  ('Medialuna', 'Hearty & Seasonal'): 3,
#  ('Medialuna', 'Soup'): 7,
#  ('Medialuna', 'Pick and Mix Bowls'): 0,
#  ('Medialuna', 'Smoothies'): 2,
#  ('Medialuna', 'Cake'): 35,
#  ('Medialuna', 'Mighty Protein'): 0,
#  ('Medialuna', 'Chicken sand'): 0,
#  ('Medialuna', 'Coke'): 7,
#  ('Medialuna', 'My-5 Fruit Shoot'): 0,
#  ('Medialuna', 'Focaccia'): 6,
#  ('Medialuna', 'Sandwich'): 20,
#  ('Medialuna', 'Alfajores'): 30,
#  ('Medialuna', 'Eggs'): 2,
#  ('Medialuna', 'Brownie'): 19,
#  ('Medialuna', 'Dulce de Leche'): 2,
#  ('Medialuna', 'Honey'): 0,
#  ('Medialuna', 'The BART'): 0,
#  ('Medialuna', 'Granola'): 1,
#  ('Medialuna', 'Fairy Doors'): 0,
#  ('Medialuna', 'Empanadas'): 1,
#  ('Medialuna', 'Keeping It Local'): 2,
#  ('Medialuna', 'Art Tray'): 1,
#  ('Medialuna', 'Bowl Nic Pitt'): 0,
#  ('Medialuna', 'Bread Pudding'): 0,
#  ('Medialuna', 'Adjustment'): 0,
#  ('Medialuna', 'Truffles'): 12,
#  ('Medialuna', 'Chimichurri Oil'): 0,
#  ('Medialuna', 'Bacon'): 0,
#  ('Medialuna', 'Spread'): 0,
#  ('Medialuna', 'Kids biscuit'): 0,
#  ('Medialuna', 'Siblings'): 0,
#  ('Medialuna', 'Caramel bites'): 1,
#  ('Medialuna', 'Jammie Dodgers'): 7,
#  ('Medialuna', 'Tiffin'): 7,
#  ('Medialuna', 'Olum & polenta'): 0,
#  ('Medialuna', 'Polenta'): 0,
#  ('Medialuna', 'The Nomad'): 4,
#  ('Medialuna', 'Hack the stack'): 0,
#  ('Medialuna', 'Bakewell'): 2,
#  ('Medialuna', 'Lemon and coconut'): 0,
#  ('Medialuna', 'Toast'): 18,
#  ('Medialuna', 'Scone'): 14,
#  ('Medialuna', 'Crepes'): 2,
#  ('Medialuna', 'Vegan mincepie'): 2,
#  ('Medialuna', 'Bare Popcorn'): 0,
#  ('Medialuna', 'Muesli'): 0,
#  ('Medialuna', 'Crisps'): 2,
#  ('Medialuna', 'Pintxos'): 0,
#  ('Medialuna', 'Gingerbread syrup'): 1,
#  ('Medialuna', 'Panatone'): 0,
#  ('Medialuna', 'Brioche and salami'): 0,
#  ('Medialuna', 'Afternoon with the baker'): 0,
#  ('Medialuna', 'Salad'): 1,
#  ('Medialuna', 'Chicken Stew'): 5,
#  ('Medialuna', 'Spanish Brunch'): 7,
#  ('Medialuna', 'Raspberry shortbread sandwich'): 0,
#  ('Medialuna', 'Extra Salami or Feta'): 0,
#  ('Medialuna', 'Duck egg'): 0,
#  ('Medialuna', 'Baguette'): 5,
#  ('Medialuna', "Valentine's card"): 0,
#  ('Medialuna', 'Tshirt'): 0,
#  ('Medialuna', 'Vegan Feast'): 0,
#  ('Medialuna', 'Postcard'): 0,
#  ('Medialuna', 'Nomad bag'): 0,
#  ('Medialuna', 'Chocolates'): 0,
#  ('Medialuna', 'Coffee granules '): 0,
#  ('Medialuna', 'Drinking chocolate spoons '): 0,
#  ('Medialuna', 'Christmas common'): 0,
#  ('Medialuna', 'Argentina Night'): 0,
#  ('Medialuna', 'Half slice Monster '): 0,
#  ('Medialuna', 'Gift voucher'): 0,
#  ('Medialuna', 'Cherry me Dried fruit'): 0,
#  ('Medialuna', 'Mortimer'): 0,
#  ('Medialuna', 'Raw bars'): 0,
#  ('Medialuna', 'Tacos/Fajita'): 0,
#  ('Tea', 'Tartine'): 9,
#  ('Tea', 'Basket'): 0,
#  ('Tea', 'Mineral water'): 12,
#  ('Tea', 'Farm House'): 15,
#  ('Tea', 'Fudge'): 11,
#  ('Tea', 'Juice'): 68,
#  ('Tea', "Ella's Kitchen Pouches"): 4,
#  ('Tea', 'Victorian Sponge'): 4,
#  ('Tea', 'Frittata'): 18,
#  ('Tea', 'Hearty & Seasonal'): 19,
#  ('Tea', 'Soup'): 86,
#  ('Tea', 'Pick and Mix Bowls'): 1,
#  ('Tea', 'Smoothies'): 9,
#  ('Tea', 'Cake'): 225,
#  ('Tea', 'Mighty Protein'): 3,
#  ('Tea', 'Chicken sand'): 1,
#  ('Tea', 'Coke'): 21,
#  ('Tea', 'My-5 Fruit Shoot'): 1,
#  ('Tea', 'Focaccia'): 5,
#  ('Tea', 'Sandwich'): 136,
#  ('Tea', 'Alfajores'): 64,
#  ('Tea', 'Eggs'): 1,
#  ('Tea', 'Brownie'): 64,
#  ('Tea', 'Dulce de Leche'): 0,
#  ('Tea', 'Honey'): 2,
#  ('Tea', 'The BART'): 0,
#  ('Tea', 'Granola'): 7,
#  ('Tea', 'Fairy Doors'): 0,
#  ('Tea', 'Empanadas'): 2,
#  ('Tea', 'Keeping It Local'): 17,
#  ('Tea', 'Art Tray'): 11,
#  ('Tea', 'Bowl Nic Pitt'): 0,
#  ('Tea', 'Bread Pudding'): 0,
#  ('Tea', 'Adjustment'): 0,
#  ('Tea', 'Truffles'): 29,
#  ('Tea', 'Chimichurri Oil'): 0,
#  ('Tea', 'Bacon'): 0,
#  ('Tea', 'Spread'): 0,
#  ('Tea', 'Kids biscuit'): 1,
#  ('Tea', 'Siblings'): 0,
#  ('Tea', 'Caramel bites'): 1,
#  ('Tea', 'Jammie Dodgers'): 24,
#  ('Tea', 'Tiffin'): 33,
#  ('Tea', 'Olum & polenta'): 0,
#  ('Tea', 'Polenta'): 1,
#  ('Tea', 'The Nomad'): 17,
#  ('Tea', 'Hack the stack'): 1,
#  ('Tea', 'Bakewell'): 12,
#  ('Tea', 'Lemon and coconut'): 2,
#  ('Tea', 'Toast'): 61,
#  ('Tea', 'Scone'): 79,
#  ('Tea', 'Crepes'): 0,
#  ('Tea', 'Vegan mincepie'): 7,
#  ('Tea', 'Bare Popcorn'): 0,
#  ('Tea', 'Muesli'): 2,
#  ('Tea', 'Crisps'): 0,
#  ('Tea', 'Pintxos'): 0,
#  ('Tea', 'Gingerbread syrup'): 1,
#  ('Tea', 'Panatone'): 0,
#  ('Tea', 'Brioche and salami'): 1,
#  ('Tea', 'Afternoon with the baker'): 3,
#  ('Tea', 'Salad'): 19,
#  ('Tea', 'Chicken Stew'): 30,
#  ('Tea', 'Spanish Brunch'): 44,
#  ('Tea', 'Raspberry shortbread sandwich'): 2,
#  ('Tea', 'Extra Salami or Feta'): 6,
#  ('Tea', 'Duck egg'): 6,
#  ('Tea', 'Baguette'): 3,
#  ('Tea', "Valentine's card"): 0,
#  ('Tea', 'Tshirt'): 0,
#  ('Tea', 'Vegan Feast'): 1,
#  ('Tea', 'Postcard'): 0,
#  ('Tea', 'Nomad bag'): 0,
#  ('Tea', 'Chocolates'): 3,
#  ('Tea', 'Coffee granules '): 0,
#  ('Tea', 'Drinking chocolate spoons '): 0,
#  ('Tea', 'Christmas common'): 1,
#  ('Tea', 'Argentina Night'): 2,
#  ('Tea', 'Half slice Monster '): 0,
#  ('Tea', 'Gift voucher'): 0,
#  ('Tea', 'Cherry me Dried fruit'): 0,
#  ('Tea', 'Mortimer'): 0,
#  ('Tea', 'Raw bars'): 1,
#  ('Tea', 'Tacos/Fajita'): 3,
#  ('Tartine', 'Basket'): 0,
#  ('Tartine', 'Mineral water'): 2,
#  ('Tartine', 'Farm House'): 1,
#  ('Tartine', 'Fudge'): 1,
#  ('Tartine', 'Juice'): 4,
#  ('Tartine', "Ella's Kitchen Pouches"): 0,
#  ('Tartine', 'Victorian Sponge'): 0,
#  ('Tartine', 'Frittata'): 0,
#  ('Tartine', 'Hearty & Seasonal'): 1,
#  ('Tartine', 'Soup'): 0,
#  ('Tartine', 'Pick and Mix Bowls'): 3,
#  ('Tartine', 'Smoothies'): 0,
#  ('Tartine', 'Cake'): 1,
#  ('Tartine', 'Mighty Protein'): 1,
#  ('Tartine', 'Chicken sand'): 0,
#  ('Tartine', 'Coke'): 1,
#  ('Tartine', 'My-5 Fruit Shoot'): 1,
#  ('Tartine', 'Focaccia'): 0,
#  ('Tartine', 'Sandwich'): 2,
#  ('Tartine', 'Alfajores'): 1,
#  ('Tartine', 'Eggs'): 0,
#  ('Tartine', 'Brownie'): 2,
#  ('Tartine', 'Dulce de Leche'): 0,
#  ('Tartine', 'Honey'): 0,
#  ('Tartine', 'The BART'): 0,
#  ('Tartine', 'Granola'): 0,
#  ('Tartine', 'Fairy Doors'): 0,
#  ('Tartine', 'Empanadas'): 0,
#  ('Tartine', 'Keeping It Local'): 0,
#  ('Tartine', 'Art Tray'): 1,
#  ('Tartine', 'Bowl Nic Pitt'): 0,
#  ('Tartine', 'Bread Pudding'): 0,
#  ('Tartine', 'Adjustment'): 0,
#  ('Tartine', 'Truffles'): 0,
#  ('Tartine', 'Chimichurri Oil'): 0,
#  ('Tartine', 'Bacon'): 0,
#  ('Tartine', 'Spread'): 0,
#  ('Tartine', 'Kids biscuit'): 0,
#  ('Tartine', 'Siblings'): 0,
#  ('Tartine', 'Caramel bites'): 0,
#  ('Tartine', 'Jammie Dodgers'): 0,
#  ('Tartine', 'Tiffin'): 0,
#  ('Tartine', 'Olum & polenta'): 0,
#  ('Tartine', 'Polenta'): 0,
#  ('Tartine', 'The Nomad'): 1,
#  ('Tartine', 'Hack the stack'): 0,
#  ('Tartine', 'Bakewell'): 0,
#  ('Tartine', 'Lemon and coconut'): 0,
#  ('Tartine', 'Toast'): 0,
#  ('Tartine', 'Scone'): 0,
#  ('Tartine', 'Crepes'): 0,
#  ('Tartine', 'Vegan mincepie'): 0,
#  ('Tartine', 'Bare Popcorn'): 0,
#  ('Tartine', 'Muesli'): 0,
#  ('Tartine', 'Crisps'): 0,
#  ('Tartine', 'Pintxos'): 0,
#  ('Tartine', 'Gingerbread syrup'): 0,
#  ('Tartine', 'Panatone'): 0,
#  ('Tartine', 'Brioche and salami'): 0,
#  ('Tartine', 'Afternoon with the baker'): 0,
#  ('Tartine', 'Salad'): 0,
#  ('Tartine', 'Chicken Stew'): 0,
#  ('Tartine', 'Spanish Brunch'): 0,
#  ('Tartine', 'Raspberry shortbread sandwich'): 0,
#  ('Tartine', 'Extra Salami or Feta'): 0,
#  ('Tartine', 'Duck egg'): 0,
#  ('Tartine', 'Baguette'): 0,
#  ('Tartine', "Valentine's card"): 0,
#  ('Tartine', 'Tshirt'): 0,
#  ('Tartine', 'Vegan Feast'): 0,
#  ('Tartine', 'Postcard'): 0,
#  ('Tartine', 'Nomad bag'): 0,
#  ('Tartine', 'Chocolates'): 0,
#  ('Tartine', 'Coffee granules '): 0,
#  ('Tartine', 'Drinking chocolate spoons '): 0,
#  ('Tartine', 'Christmas common'): 0,
#  ('Tartine', 'Argentina Night'): 0,
#  ('Tartine', 'Half slice Monster '): 0,
#  ('Tartine', 'Gift voucher'): 0,
#  ('Tartine', 'Cherry me Dried fruit'): 0,
#  ('Tartine', 'Mortimer'): 0,
#  ('Tartine', 'Raw bars'): 0,
#  ('Tartine', 'Tacos/Fajita'): 0,
#  ('Basket', 'Mineral water'): 0,
#  ('Basket', 'Farm House'): 1,
#  ('Basket', 'Fudge'): 0,
#  ('Basket', 'Juice'): 0,
#  ('Basket', "Ella's Kitchen Pouches"): 0,
#  ('Basket', 'Victorian Sponge'): 0,
#  ('Basket', 'Frittata'): 0,
#  ('Basket', 'Hearty & Seasonal'): 0,
#  ('Basket', 'Soup'): 0,
#  ('Basket', 'Pick and Mix Bowls'): 0,
#  ('Basket', 'Smoothies'): 0,
#  ('Basket', 'Cake'): 0,
#  ('Basket', 'Mighty Protein'): 0,
#  ('Basket', 'Chicken sand'): 0,
#  ('Basket', 'Coke'): 0,
#  ('Basket', 'My-5 Fruit Shoot'): 0,
#  ('Basket', 'Focaccia'): 0,
#  ('Basket', 'Sandwich'): 0,
#  ('Basket', 'Alfajores'): 0,
#  ('Basket', 'Eggs'): 0,
#  ('Basket', 'Brownie'): 0,
#  ('Basket', 'Dulce de Leche'): 0,
#  ('Basket', 'Honey'): 0,
#  ('Basket', 'The BART'): 0,
#  ('Basket', 'Granola'): 0,
#  ('Basket', 'Fairy Doors'): 0,
#  ('Basket', 'Empanadas'): 0,
#  ('Basket', 'Keeping It Local'): 0,
#  ('Basket', 'Art Tray'): 0,
#  ('Basket', 'Bowl Nic Pitt'): 0,
#  ('Basket', 'Bread Pudding'): 0,
#  ('Basket', 'Adjustment'): 0,
#  ...}

# %%
def getMostAndLeastPopulor(combs_dict):
    max_value = max(combs_dict.values())
    min_value = min(combs_dict.values())
    max_combs = []
    min_combs = []
    for k, v in combs_dict.items():
        if v == max_value:
            max_combs.append(k)
        if v == min_value:
            min_combs.append(k)
    return max_combs, min_combs

# %%
most_combs, least_combs = getMostAndLeastPopulor(combs_dict)

# %%
most_combs
# Out:
# [('Bread', 'Coffee')]

# %%
least_combs
# Out:
# [('Bread', 'Mighty Protein'),
#  ('Bread', 'Chicken sand'),
#  ('Bread', 'Fairy Doors'),
#  ('Bread', 'Bowl Nic Pitt'),
#  ('Bread', 'Bread Pudding'),
#  ('Bread', 'Adjustment'),
#  ('Bread', 'Chimichurri Oil'),
#  ('Bread', 'Bacon'),
#  ('Bread', 'Siblings'),
#  ('Bread', 'Polenta'),
#  ('Bread', 'Hack the stack'),
#  ('Bread', 'Bare Popcorn'),
#  ('Bread', 'Pintxos'),
#  ('Bread', "Valentine's card"),
#  ('Bread', 'Postcard'),
#  ('Bread', 'Coffee granules '),
#  ('Bread', 'Half slice Monster '),
#  ('Bread', 'Cherry me Dried fruit'),
#  ('Bread', 'Mortimer'),
#  ('Bread', 'Raw bars'),
#  ('Scandinavian', 'Basket'),
#  ('Scandinavian', "Ella's Kitchen Pouches"),
#  ('Scandinavian', 'Pick and Mix Bowls'),
#  ('Scandinavian', 'Smoothies'),
#  ('Scandinavian', 'Mighty Protein'),
#  ('Scandinavian', 'Coke'),
#  ('Scandinavian', 'The BART'),
#  ('Scandinavian', 'Art Tray'),
#  ('Scandinavian', 'Bowl Nic Pitt'),
#  ('Scandinavian', 'Bread Pudding'),
#  ('Scandinavian', 'Adjustment'),
#  ('Scandinavian', 'Bacon'),
#  ('Scandinavian', 'Spread'),
#  ('Scandinavian', 'Kids biscuit'),
#  ('Scandinavian', 'Siblings'),
#  ('Scandinavian', 'Caramel bites'),
#  ('Scandinavian', 'Tiffin'),
#  ('Scandinavian', 'Olum & polenta'),
#  ('Scandinavian', 'Polenta'),
#  ('Scandinavian', 'The Nomad'),
#  ('Scandinavian', 'Hack the stack'),
#  ('Scandinavian', 'Bakewell'),
#  ('Scandinavian', 'Lemon and coconut'),
#  ('Scandinavian', 'Crepes'),
#  ('Scandinavian', 'Bare Popcorn'),
#  ('Scandinavian', 'Muesli'),
#  ('Scandinavian', 'Crisps'),
#  ('Scandinavian', 'Pintxos'),
#  ('Scandinavian', 'Gingerbread syrup'),
#  ('Scandinavian', 'Panatone'),
#  ('Scandinavian', 'Brioche and salami'),
#  ('Scandinavian', 'Chicken Stew'),
#  ('Scandinavian', 'Spanish Brunch'),
#  ('Scandinavian', 'Raspberry shortbread sandwich'),
#  ('Scandinavian', 'Duck egg'),
#  ('Scandinavian', "Valentine's card"),
#  ('Scandinavian', 'Tshirt'),
#  ('Scandinavian', 'Vegan Feast'),
#  ('Scandinavian', 'Postcard'),
#  ('Scandinavian', 'Chocolates'),
#  ('Scandinavian', 'Coffee granules '),
#  ('Scandinavian', 'Drinking chocolate spoons '),
#  ('Scandinavian', 'Argentina Night'),
#  ('Scandinavian', 'Half slice Monster '),
#  ('Scandinavian', 'Gift voucher'),
#  ('Scandinavian', 'Cherry me Dried fruit'),
#  ('Scandinavian', 'Mortimer'),
#  ('Scandinavian', 'Raw bars'),
#  ('Scandinavian', 'Tacos/Fajita'),
#  ('Hot chocolate', "Ella's Kitchen Pouches"),
#  ('Hot chocolate', 'Frittata'),
#  ('Hot chocolate', 'Mighty Protein'),
#  ('Hot chocolate', 'Chicken sand'),
#  ('Hot chocolate', 'Focaccia'),
#  ('Hot chocolate', 'Dulce de Leche'),
#  ('Hot chocolate', 'Honey'),
#  ('Hot chocolate', 'The BART'),
#  ('Hot chocolate', 'Fairy Doors'),
#  ('Hot chocolate', 'Empanadas'),
#  ('Hot chocolate', 'Bowl Nic Pitt'),
#  ('Hot chocolate', 'Bread Pudding'),
#  ('Hot chocolate', 'Adjustment'),
#  ('Hot chocolate', 'Chimichurri Oil'),
#  ('Hot chocolate', 'Bacon'),
#  ('Hot chocolate', 'Spread'),
#  ('Hot chocolate', 'Kids biscuit'),
#  ('Hot chocolate', 'Siblings'),
#  ('Hot chocolate', 'Caramel bites'),
#  ('Hot chocolate', 'Olum & polenta'),
#  ('Hot chocolate', 'Polenta'),
#  ('Hot chocolate', 'Hack the stack'),
#  ('Hot chocolate', 'Crepes'),
#  ('Hot chocolate', 'Muesli'),
#  ('Hot chocolate', 'Pintxos'),
#  ('Hot chocolate', 'Gingerbread syrup'),
#  ('Hot chocolate', 'Panatone'),
#  ('Hot chocolate', 'Brioche and salami'),
#  ('Hot chocolate', 'Raspberry shortbread sandwich'),
#  ('Hot chocolate', "Valentine's card"),
#  ('Hot chocolate', 'Postcard'),
#  ('Hot chocolate', 'Nomad bag'),
#  ('Hot chocolate', 'Coffee granules '),
#  ('Hot chocolate', 'Argentina Night'),
#  ('Hot chocolate', 'Gift voucher'),
#  ('Hot chocolate', 'Mortimer'),
#  ('Hot chocolate', 'Raw bars'),
#  ('Hot chocolate', 'Tacos/Fajita'),
#  ('Jam', 'Basket'),
#  ('Jam', 'Victorian Sponge'),
#  ('Jam', 'Hearty & Seasonal'),
#  ('Jam', 'Mighty Protein'),
#  ('Jam', 'Chicken sand'),
#  ('Jam', 'Coke'),
#  ('Jam', 'My-5 Fruit Shoot'),
#  ('Jam', 'Eggs'),
#  ('Jam', 'Dulce de Leche'),
#  ('Jam', 'Honey'),
#  ('Jam', 'The BART'),
#  ('Jam', 'Granola'),
#  ('Jam', 'Fairy Doors'),
#  ('Jam', 'Empanadas'),
#  ('Jam', 'Art Tray'),
#  ('Jam', 'Bowl Nic Pitt'),
#  ('Jam', 'Adjustment'),
#  ('Jam', 'Chimichurri Oil'),
#  ('Jam', 'Bacon'),
#  ('Jam', 'Kids biscuit'),
#  ('Jam', 'Siblings'),
#  ('Jam', 'Caramel bites'),
#  ('Jam', 'Jammie Dodgers'),
#  ('Jam', 'Tiffin'),
#  ('Jam', 'Olum & polenta'),
#  ('Jam', 'Polenta'),
#  ('Jam', 'Hack the stack'),
#  ('Jam', 'Bakewell'),
#  ('Jam', 'Lemon and coconut'),
#  ('Jam', 'Crepes'),
#  ('Jam', 'Vegan mincepie'),
#  ('Jam', 'Bare Popcorn'),
#  ('Jam', 'Muesli'),
#  ('Jam', 'Crisps'),
#  ('Jam', 'Pintxos'),
#  ('Jam', 'Panatone'),
#  ('Jam', 'Brioche and salami'),
#  ('Jam', 'Afternoon with the baker'),
#  ('Jam', 'Chicken Stew'),
#  ('Jam', 'Raspberry shortbread sandwich'),
#  ('Jam', 'Baguette'),
#  ('Jam', "Valentine's card"),
#  ('Jam', 'Tshirt'),
#  ('Jam', 'Vegan Feast'),
#  ('Jam', 'Postcard'),
#  ('Jam', 'Nomad bag'),
#  ('Jam', 'Chocolates'),
#  ('Jam', 'Coffee granules '),
#  ('Jam', 'Drinking chocolate spoons '),
#  ('Jam', 'Argentina Night'),
#  ('Jam', 'Half slice Monster '),
#  ('Jam', 'Gift voucher'),
#  ('Jam', 'Cherry me Dried fruit'),
#  ('Jam', 'Mortimer'),
#  ('Jam', 'Raw bars'),
#  ('Jam', 'Tacos/Fajita'),
#  ('Cookies', 'Basket'),
#  ('Cookies', 'Victorian Sponge'),
#  ('Cookies', 'Mighty Protein'),
#  ('Cookies', 'Chicken sand'),
#  ('Cookies', 'Dulce de Leche'),
#  ('Cookies', 'The BART'),
#  ('Cookies', 'Fairy Doors'),
#  ('Cookies', 'Empanadas'),
#  ('Cookies', 'Bowl Nic Pitt'),
#  ('Cookies', 'Bread Pudding'),
#  ('Cookies', 'Adjustment'),
#  ('Cookies', 'Chimichurri Oil'),
#  ('Cookies', 'Bacon'),
#  ('Cookies', 'Spread'),
#  ('Cookies', 'Kids biscuit'),
#  ('Cookies', 'Siblings'),
#  ('Cookies', 'Caramel bites'),
#  ('Cookies', 'Olum & polenta'),
#  ('Cookies', 'Polenta'),
#  ('Cookies', 'Hack the stack'),
#  ('Cookies', 'Lemon and coconut'),
#  ('Cookies', 'Crepes'),
#  ('Cookies', 'Pintxos'),
#  ('Cookies', 'Gingerbread syrup'),
#  ('Cookies', 'Brioche and salami'),
#  ('Cookies', 'Raspberry shortbread sandwich'),
#  ('Cookies', "Valentine's card"),
#  ('Cookies', 'Tshirt'),
#  ('Cookies', 'Postcard'),
#  ('Cookies', 'Nomad bag'),
#  ('Cookies', 'Coffee granules '),
#  ('Cookies', 'Drinking chocolate spoons '),
#  ('Cookies', 'Christmas common'),
#  ('Cookies', 'Argentina Night'),
#  ('Cookies', 'Gift voucher'),
#  ('Cookies', 'Cherry me Dried fruit'),
#  ('Cookies', 'Mortimer'),
#  ('Cookies', 'Raw bars'),
#  ('Cookies', 'Tacos/Fajita'),
#  ('Muffin', 'Basket'),
#  ('Muffin', 'Victorian Sponge'),
#  ('Muffin', 'Pick and Mix Bowls'),
#  ('Muffin', 'Mighty Protein'),
#  ('Muffin', 'Chicken sand'),
#  ('Muffin', 'Eggs'),
#  ('Muffin', 'Dulce de Leche'),
#  ('Muffin', 'Honey'),
#  ('Muffin', 'The BART'),
#  ('Muffin', 'Fairy Doors'),
#  ('Muffin', 'Bread Pudding'),
#  ('Muffin', 'Adjustment'),
#  ('Muffin', 'Chimichurri Oil'),
#  ('Muffin', 'Bacon'),
#  ('Muffin', 'Spread'),
#  ('Muffin', 'Siblings'),
#  ('Muffin', 'Caramel bites'),
#  ('Muffin', 'Olum & polenta'),
#  ('Muffin', 'Polenta'),
#  ('Muffin', 'Hack the stack'),
#  ('Muffin', 'Lemon and coconut'),
#  ('Muffin', 'Crepes'),
#  ('Muffin', 'Vegan mincepie'),
#  ('Muffin', 'Muesli'),
#  ('Muffin', 'Crisps'),
#  ('Muffin', 'Pintxos'),
#  ('Muffin', 'Brioche and salami'),
#  ('Muffin', 'Afternoon with the baker'),
#  ('Muffin', 'Raspberry shortbread sandwich'),
#  ('Muffin', 'Duck egg'),
#  ('Muffin', "Valentine's card"),
#  ('Muffin', 'Tshirt'),
#  ('Muffin', 'Postcard'),
#  ('Muffin', 'Nomad bag'),
#  ('Muffin', 'Chocolates'),
#  ('Muffin', 'Coffee granules '),
#  ('Muffin', 'Christmas common'),
#  ('Muffin', 'Argentina Night'),
#  ('Muffin', 'Half slice Monster '),
#  ('Muffin', 'Gift voucher'),
#  ('Muffin', 'Cherry me Dried fruit'),
#  ('Muffin', 'Mortimer'),
#  ('Muffin', 'Raw bars'),
#  ('Coffee', 'Victorian Sponge'),
#  ('Coffee', 'The BART'),
#  ('Coffee', 'Fairy Doors'),
#  ('Coffee', 'Adjustment'),
#  ('Coffee', 'Chimichurri Oil'),
#  ('Coffee', 'Spread'),
#  ('Coffee', 'Siblings'),
#  ('Coffee', 'Olum & polenta'),
#  ('Coffee', 'Polenta'),
#  ('Coffee', 'Pintxos'),
#  ('Coffee', "Valentine's card"),
#  ('Coffee', 'Christmas common'),
#  ('Coffee', 'Argentina Night'),
#  ('Coffee', 'Gift voucher'),
#  ('Coffee', 'Mortimer'),
#  ('Coffee', 'Raw bars'),
#  ('Pastry', 'Basket'),
#  ('Pastry', 'Victorian Sponge'),
#  ('Pastry', 'Pick and Mix Bowls'),
#  ('Pastry', 'Mighty Protein'),
#  ('Pastry', 'Chicken sand'),
#  ('Pastry', 'The BART'),
#  ('Pastry', 'Fairy Doors'),
#  ('Pastry', 'Empanadas'),
#  ('Pastry', 'Bowl Nic Pitt'),
#  ('Pastry', 'Bread Pudding'),
#  ('Pastry', 'Adjustment'),
#  ('Pastry', 'Chimichurri Oil'),
#  ('Pastry', 'Bacon'),
#  ('Pastry', 'Spread'),
#  ('Pastry', 'Kids biscuit'),
#  ('Pastry', 'Siblings'),
#  ('Pastry', 'Caramel bites'),
#  ('Pastry', 'Olum & polenta'),
#  ('Pastry', 'Polenta'),
#  ('Pastry', 'Hack the stack'),
#  ('Pastry', 'Lemon and coconut'),
#  ('Pastry', 'Crepes'),
#  ('Pastry', 'Bare Popcorn'),
#  ('Pastry', 'Muesli'),
#  ('Pastry', 'Crisps'),
#  ('Pastry', 'Pintxos'),
#  ('Pastry', 'Panatone'),
#  ('Pastry', 'Brioche and salami'),
#  ('Pastry', 'Afternoon with the baker'),
#  ('Pastry', 'Raspberry shortbread sandwich'),
#  ('Pastry', 'Extra Salami or Feta'),
#  ('Pastry', 'Duck egg'),
#  ('Pastry', "Valentine's card"),
#  ('Pastry', 'Tshirt'),
#  ('Pastry', 'Postcard'),
#  ('Pastry', 'Coffee granules '),
#  ('Pastry', 'Christmas common'),
#  ('Pastry', 'Argentina Night'),
#  ('Pastry', 'Half slice Monster '),
#  ('Pastry', 'Gift voucher'),
#  ('Pastry', 'Cherry me Dried fruit'),
#  ('Pastry', 'Mortimer'),
#  ('Pastry', 'Raw bars'),
#  ('Pastry', 'Tacos/Fajita'),
#  ('Medialuna', 'Basket'),
#  ('Medialuna', 'Victorian Sponge'),
#  ('Medialuna', 'Pick and Mix Bowls'),
#  ('Medialuna', 'Mighty Protein'),
#  ('Medialuna', 'Chicken sand'),
#  ('Medialuna', 'My-5 Fruit Shoot'),
#  ('Medialuna', 'Honey'),
#  ('Medialuna', 'The BART'),
#  ('Medialuna', 'Fairy Doors'),
#  ('Medialuna', 'Bowl Nic Pitt'),
#  ('Medialuna', 'Bread Pudding'),
#  ('Medialuna', 'Adjustment'),
#  ('Medialuna', 'Chimichurri Oil'),
#  ('Medialuna', 'Bacon'),
#  ('Medialuna', 'Spread'),
#  ('Medialuna', 'Kids biscuit'),
#  ('Medialuna', 'Siblings'),
#  ('Medialuna', 'Olum & polenta'),
#  ('Medialuna', 'Polenta'),
#  ('Medialuna', 'Hack the stack'),
#  ('Medialuna', 'Lemon and coconut'),
#  ('Medialuna', 'Bare Popcorn'),
#  ('Medialuna', 'Muesli'),
#  ('Medialuna', 'Pintxos'),
#  ('Medialuna', 'Panatone'),
#  ('Medialuna', 'Brioche and salami'),
#  ('Medialuna', 'Afternoon with the baker'),
#  ('Medialuna', 'Raspberry shortbread sandwich'),
#  ('Medialuna', 'Extra Salami or Feta'),
#  ('Medialuna', 'Duck egg'),
#  ('Medialuna', "Valentine's card"),
#  ('Medialuna', 'Tshirt'),
#  ('Medialuna', 'Vegan Feast'),
#  ('Medialuna', 'Postcard'),
#  ('Medialuna', 'Nomad bag'),
#  ('Medialuna', 'Chocolates'),
#  ('Medialuna', 'Coffee granules '),
#  ('Medialuna', 'Drinking chocolate spoons '),
#  ('Medialuna', 'Christmas common'),
#  ('Medialuna', 'Argentina Night'),
#  ('Medialuna', 'Half slice Monster '),
#  ('Medialuna', 'Gift voucher'),
#  ('Medialuna', 'Cherry me Dried fruit'),
#  ('Medialuna', 'Mortimer'),
#  ('Medialuna', 'Raw bars'),
#  ('Medialuna', 'Tacos/Fajita'),
#  ('Tea', 'Basket'),
#  ('Tea', 'Dulce de Leche'),
#  ('Tea', 'The BART'),
#  ('Tea', 'Fairy Doors'),
#  ('Tea', 'Bowl Nic Pitt'),
#  ('Tea', 'Bread Pudding'),
#  ('Tea', 'Adjustment'),
#  ('Tea', 'Chimichurri Oil'),
#  ('Tea', 'Bacon'),
#  ('Tea', 'Spread'),
#  ('Tea', 'Siblings'),
#  ('Tea', 'Olum & polenta'),
#  ('Tea', 'Crepes'),
#  ('Tea', 'Bare Popcorn'),
#  ('Tea', 'Crisps'),
#  ('Tea', 'Pintxos'),
#  ('Tea', 'Panatone'),
#  ('Tea', "Valentine's card"),
#  ('Tea', 'Tshirt'),
#  ('Tea', 'Postcard'),
#  ('Tea', 'Nomad bag'),
#  ('Tea', 'Coffee granules '),
#  ('Tea', 'Drinking chocolate spoons '),
#  ('Tea', 'Half slice Monster '),
#  ('Tea', 'Gift voucher'),
#  ('Tea', 'Cherry me Dried fruit'),
#  ('Tea', 'Mortimer'),
#  ('Tartine', 'Basket'),
#  ('Tartine', "Ella's Kitchen Pouches"),
#  ('Tartine', 'Victorian Sponge'),
#  ('Tartine', 'Frittata'),
#  ('Tartine', 'Soup'),
#  ('Tartine', 'Smoothies'),
#  ('Tartine', 'Chicken sand'),
#  ('Tartine', 'Focaccia'),
#  ('Tartine', 'Eggs'),
#  ('Tartine', 'Dulce de Leche'),
#  ('Tartine', 'Honey'),
#  ('Tartine', 'The BART'),
#  ('Tartine', 'Granola'),
#  ('Tartine', 'Fairy Doors'),
#  ('Tartine', 'Empanadas'),
#  ('Tartine', 'Keeping It Local'),
#  ('Tartine', 'Bowl Nic Pitt'),
#  ('Tartine', 'Bread Pudding'),
#  ('Tartine', 'Adjustment'),
#  ('Tartine', 'Truffles'),
#  ('Tartine', 'Chimichurri Oil'),
#  ('Tartine', 'Bacon'),
#  ('Tartine', 'Spread'),
#  ('Tartine', 'Kids biscuit'),
#  ('Tartine', 'Siblings'),
#  ('Tartine', 'Caramel bites'),
#  ('Tartine', 'Jammie Dodgers'),
#  ('Tartine', 'Tiffin'),
#  ('Tartine', 'Olum & polenta'),
#  ('Tartine', 'Polenta'),
#  ('Tartine', 'Hack the stack'),
#  ('Tartine', 'Bakewell'),
#  ('Tartine', 'Lemon and coconut'),
#  ('Tartine', 'Toast'),
#  ('Tartine', 'Scone'),
#  ('Tartine', 'Crepes'),
#  ('Tartine', 'Vegan mincepie'),
#  ('Tartine', 'Bare Popcorn'),
#  ('Tartine', 'Muesli'),
#  ('Tartine', 'Crisps'),
#  ('Tartine', 'Pintxos'),
#  ('Tartine', 'Gingerbread syrup'),
#  ('Tartine', 'Panatone'),
#  ('Tartine', 'Brioche and salami'),
#  ('Tartine', 'Afternoon with the baker'),
#  ('Tartine', 'Salad'),
#  ('Tartine', 'Chicken Stew'),
#  ('Tartine', 'Spanish Brunch'),
#  ('Tartine', 'Raspberry shortbread sandwich'),
#  ('Tartine', 'Extra Salami or Feta'),
#  ('Tartine', 'Duck egg'),
#  ('Tartine', 'Baguette'),
#  ('Tartine', "Valentine's card"),
#  ('Tartine', 'Tshirt'),
#  ('Tartine', 'Vegan Feast'),
#  ('Tartine', 'Postcard'),
#  ('Tartine', 'Nomad bag'),
#  ('Tartine', 'Chocolates'),
#  ('Tartine', 'Coffee granules '),
#  ('Tartine', 'Drinking chocolate spoons '),
#  ('Tartine', 'Christmas common'),
#  ('Tartine', 'Argentina Night'),
#  ('Tartine', 'Half slice Monster '),
#  ('Tartine', 'Gift voucher'),
#  ('Tartine', 'Cherry me Dried fruit'),
#  ('Tartine', 'Mortimer'),
#  ('Tartine', 'Raw bars'),
#  ('Tartine', 'Tacos/Fajita'),
#  ('Basket', 'Mineral water'),
#  ('Basket', 'Fudge'),
#  ('Basket', 'Juice'),
#  ('Basket', "Ella's Kitchen Pouches"),
#  ('Basket', 'Victorian Sponge'),
#  ('Basket', 'Frittata'),
#  ('Basket', 'Hearty & Seasonal'),
#  ('Basket', 'Soup'),
#  ('Basket', 'Pick and Mix Bowls'),
#  ('Basket', 'Smoothies'),
#  ('Basket', 'Cake'),
#  ('Basket', 'Mighty Protein'),
#  ('Basket', 'Chicken sand'),
#  ('Basket', 'Coke'),
#  ('Basket', 'My-5 Fruit Shoot'),
#  ('Basket', 'Focaccia'),
#  ('Basket', 'Sandwich'),
#  ('Basket', 'Alfajores'),
#  ('Basket', 'Eggs'),
#  ('Basket', 'Brownie'),
#  ('Basket', 'Dulce de Leche'),
#  ('Basket', 'Honey'),
#  ('Basket', 'The BART'),
#  ('Basket', 'Granola'),
#  ('Basket', 'Fairy Doors'),
#  ('Basket', 'Empanadas'),
#  ('Basket', 'Keeping It Local'),
#  ('Basket', 'Art Tray'),
#  ('Basket', 'Bowl Nic Pitt'),
#  ('Basket', 'Bread Pudding'),
#  ('Basket', 'Adjustment'),
#  ('Basket', 'Truffles'),
#  ('Basket', 'Chimichurri Oil'),
#  ('Basket', 'Bacon'),
#  ('Basket', 'Spread'),
#  ('Basket', 'Kids biscuit'),
#  ('Basket', 'Siblings'),
#  ('Basket', 'Caramel bites'),
#  ('Basket', 'Jammie Dodgers'),
#  ('Basket', 'Tiffin'),
#  ('Basket', 'Olum & polenta'),
#  ('Basket', 'Polenta'),
#  ('Basket', 'The Nomad'),
#  ('Basket', 'Hack the stack'),
#  ('Basket', 'Bakewell'),
#  ('Basket', 'Lemon and coconut'),
#  ('Basket', 'Toast'),
#  ('Basket', 'Scone'),
#  ('Basket', 'Crepes'),
#  ('Basket', 'Vegan mincepie'),
#  ('Basket', 'Bare Popcorn'),
#  ('Basket', 'Muesli'),
#  ('Basket', 'Crisps'),
#  ('Basket', 'Pintxos'),
#  ('Basket', 'Gingerbread syrup'),
#  ('Basket', 'Panatone'),
#  ('Basket', 'Brioche and salami'),
#  ('Basket', 'Afternoon with the baker'),
#  ('Basket', 'Salad'),
#  ('Basket', 'Chicken Stew'),
#  ('Basket', 'Spanish Brunch'),
#  ('Basket', 'Raspberry shortbread sandwich'),
#  ('Basket', 'Extra Salami or Feta'),
#  ('Basket', 'Duck egg'),
#  ('Basket', 'Baguette'),
#  ('Basket', "Valentine's card"),
#  ('Basket', 'Tshirt'),
#  ('Basket', 'Vegan Feast'),
#  ('Basket', 'Postcard'),
#  ('Basket', 'Nomad bag'),
#  ('Basket', 'Chocolates'),
#  ('Basket', 'Coffee granules '),
#  ('Basket', 'Drinking chocolate spoons '),
#  ('Basket', 'Christmas common'),
#  ('Basket', 'Argentina Night'),
#  ('Basket', 'Half slice Monster '),
#  ('Basket', 'Gift voucher'),
#  ('Basket', 'Cherry me Dried fruit'),
#  ('Basket', 'Mortimer'),
#  ('Basket', 'Raw bars'),
#  ('Basket', 'Tacos/Fajita'),
#  ('Mineral water', 'Fudge'),
#  ('Mineral water', "Ella's Kitchen Pouches"),
#  ('Mineral water', 'Victorian Sponge'),
#  ('Mineral water', 'Mighty Protein'),
#  ('Mineral water', 'Chicken sand'),
#  ('Mineral water', 'My-5 Fruit Shoot'),
#  ('Mineral water', 'Focaccia'),
#  ('Mineral water', 'Eggs'),
#  ('Mineral water', 'Dulce de Leche'),
#  ('Mineral water', 'Honey'),
#  ('Mineral water', 'The BART'),
#  ('Mineral water', 'Fairy Doors'),
#  ('Mineral water', 'Empanadas'),
#  ('Mineral water', 'Keeping It Local'),
#  ('Mineral water', 'Art Tray'),
#  ('Mineral water', 'Bowl Nic Pitt'),
#  ('Mineral water', 'Bread Pudding'),
#  ('Mineral water', 'Adjustment'),
#  ('Mineral water', 'Chimichurri Oil'),
#  ('Mineral water', 'Bacon'),
#  ('Mineral water', 'Spread'),
#  ('Mineral water', 'Siblings'),
#  ('Mineral water', 'Caramel bites'),
#  ('Mineral water', 'Jammie Dodgers'),
#  ('Mineral water', 'Olum & polenta'),
#  ('Mineral water', 'Polenta'),
#  ('Mineral water', 'The Nomad'),
#  ('Mineral water', 'Hack the stack'),
#  ('Mineral water', 'Lemon and coconut'),
#  ('Mineral water', 'Crepes'),
#  ('Mineral water', 'Bare Popcorn'),
#  ('Mineral water', 'Muesli'),
#  ('Mineral water', 'Pintxos'),
#  ('Mineral water', 'Gingerbread syrup'),
#  ('Mineral water', 'Panatone'),
#  ('Mineral water', 'Brioche and salami'),
#  ('Mineral water', 'Afternoon with the baker'),
#  ('Mineral water', 'Raspberry shortbread sandwich'),
#  ('Mineral water', 'Duck egg'),
#  ('Mineral water', 'Baguette'),
#  ('Mineral water', "Valentine's card"),
#  ('Mineral water', 'Tshirt'),
#  ('Mineral water', 'Vegan Feast'),
#  ('Mineral water', 'Postcard'),
#  ('Mineral water', 'Nomad bag'),
#  ('Mineral water', 'Coffee granules '),
#  ('Mineral water', 'Christmas common'),
#  ('Mineral water', 'Argentina Night'),
#  ('Mineral water', 'Half slice Monster '),
#  ('Mineral water', 'Gift voucher'),
#  ('Mineral water', 'Cherry me Dried fruit'),
#  ('Mineral water', 'Mortimer'),
#  ('Mineral water', 'Raw bars'),
#  ('Mineral water', 'Tacos/Fajita'),
#  ('Farm House', "Ella's Kitchen Pouches"),
#  ('Farm House', 'Victorian Sponge'),
#  ('Farm House', 'Pick and Mix Bowls'),
#  ('Farm House', 'Mighty Protein'),
#  ('Farm House', 'Chicken sand'),
#  ('Farm House', 'My-5 Fruit Shoot'),
#  ('Farm House', 'Dulce de Leche'),
#  ('Farm House', 'Honey'),
#  ('Farm House', 'The BART'),
#  ('Farm House', 'Granola'),
#  ('Farm House', 'Fairy Doors'),
#  ('Farm House', 'Empanadas'),
#  ('Farm House', 'Art Tray'),
#  ('Farm House', 'Bowl Nic Pitt'),
#  ('Farm House', 'Bread Pudding'),
#  ('Farm House', 'Adjustment'),
#  ('Farm House', 'Bacon'),
#  ('Farm House', 'Spread'),
#  ('Farm House', 'Kids biscuit'),
#  ('Farm House', 'Siblings'),
#  ('Farm House', 'Caramel bites'),
#  ('Farm House', 'Olum & polenta'),
#  ('Farm House', 'Polenta'),
#  ('Farm House', 'Hack the stack'),
#  ('Farm House', 'Lemon and coconut'),
#  ('Farm House', 'Vegan mincepie'),
#  ('Farm House', 'Muesli'),
#  ('Farm House', 'Crisps'),
#  ('Farm House', 'Pintxos'),
#  ('Farm House', 'Panatone'),
#  ('Farm House', 'Brioche and salami'),
#  ('Farm House', 'Afternoon with the baker'),
#  ('Farm House', 'Raspberry shortbread sandwich'),
#  ('Farm House', 'Duck egg'),
#  ('Farm House', "Valentine's card"),
#  ('Farm House', 'Tshirt'),
#  ('Farm House', 'Vegan Feast'),
#  ('Farm House', 'Postcard'),
#  ('Farm House', 'Chocolates'),
#  ('Farm House', 'Drinking chocolate spoons '),
#  ('Farm House', 'Christmas common'),
#  ('Farm House', 'Argentina Night'),
#  ('Farm House', 'Half slice Monster '),
#  ('Farm House', 'Gift voucher'),
#  ('Farm House', 'Cherry me Dried fruit'),
#  ('Farm House', 'Mortimer'),
#  ('Farm House', 'Raw bars'),
#  ('Farm House', 'Tacos/Fajita'),
#  ('Fudge', 'Victorian Sponge'),
#  ('Fudge', 'Hearty & Seasonal'),
#  ('Fudge', 'Pick and Mix Bowls'),
#  ('Fudge', 'Mighty Protein'),
#  ('Fudge', 'Chicken sand'),
#  ('Fudge', 'Honey'),
#  ('Fudge', 'The BART'),
#  ('Fudge', 'Fairy Doors'),
#  ('Fudge', 'Empanadas'),
#  ('Fudge', 'Art Tray'),
#  ('Fudge', 'Bowl Nic Pitt'),
#  ('Fudge', 'Adjustment'),
#  ('Fudge', 'Chimichurri Oil'),
#  ('Fudge', 'Bacon'),
#  ('Fudge', 'Siblings'),
#  ('Fudge', 'Caramel bites'),
#  ('Fudge', 'Tiffin'),
#  ('Fudge', 'Olum & polenta'),
#  ('Fudge', 'Polenta'),
#  ('Fudge', 'Hack the stack'),
#  ('Fudge', 'Bakewell'),
#  ('Fudge', 'Lemon and coconut'),
#  ('Fudge', 'Crepes'),
#  ('Fudge', 'Vegan mincepie'),
#  ('Fudge', 'Bare Popcorn'),
#  ('Fudge', 'Muesli'),
#  ('Fudge', 'Crisps'),
#  ('Fudge', 'Pintxos'),
#  ('Fudge', 'Brioche and salami'),
#  ('Fudge', 'Afternoon with the baker'),
#  ('Fudge', 'Salad'),
#  ('Fudge', 'Raspberry shortbread sandwich'),
#  ('Fudge', 'Extra Salami or Feta'),
#  ('Fudge', 'Duck egg'),
#  ('Fudge', "Valentine's card"),
#  ('Fudge', 'Vegan Feast'),
#  ('Fudge', 'Postcard'),
#  ('Fudge', 'Nomad bag'),
#  ('Fudge', 'Chocolates'),
#  ('Fudge', 'Coffee granules '),
#  ('Fudge', 'Drinking chocolate spoons '),
#  ('Fudge', 'Christmas common'),
#  ('Fudge', 'Argentina Night'),
#  ('Fudge', 'Half slice Monster '),
#  ('Fudge', 'Gift voucher'),
#  ('Fudge', 'Cherry me Dried fruit'),
#  ('Fudge', 'Mortimer'),
#  ('Fudge', 'Raw bars'),
#  ('Fudge', 'Tacos/Fajita'),
#  ('Juice', 'Victorian Sponge'),
#  ('Juice', 'Chicken sand'),
#  ('Juice', 'Dulce de Leche'),
#  ('Juice', 'Honey'),
#  ('Juice', 'The BART'),
#  ('Juice', 'Fairy Doors'),
#  ('Juice', 'Empanadas'),
#  ('Juice', 'Keeping It Local'),
#  ('Juice', 'Bowl Nic Pitt'),
#  ('Juice', 'Bread Pudding'),
#  ('Juice', 'Adjustment'),
#  ('Juice', 'Chimichurri Oil'),
#  ('Juice', 'Spread'),
#  ('Juice', 'Kids biscuit'),
#  ('Juice', 'Siblings'),
#  ('Juice', 'Caramel bites'),
#  ('Juice', 'Olum & polenta'),
#  ('Juice', 'Polenta'),
#  ('Juice', 'Hack the stack'),
#  ('Juice', 'Crepes'),
#  ('Juice', 'Muesli'),
#  ('Juice', 'Pintxos'),
#  ('Juice', 'Brioche and salami'),
#  ('Juice', 'Raspberry shortbread sandwich'),
#  ('Juice', 'Duck egg'),
#  ('Juice', "Valentine's card"),
#  ('Juice', 'Tshirt'),
#  ('Juice', 'Vegan Feast'),
#  ('Juice', 'Postcard'),
#  ('Juice', 'Coffee granules '),
#  ('Juice', 'Christmas common'),
#  ('Juice', 'Argentina Night'),
#  ('Juice', 'Gift voucher'),
#  ('Juice', 'Cherry me Dried fruit'),
#  ('Juice', 'Mortimer'),
#  ('Juice', 'Raw bars'),
#  ("Ella's Kitchen Pouches", 'Victorian Sponge'),
#  ("Ella's Kitchen Pouches", 'Frittata'),
#  ("Ella's Kitchen Pouches", 'Hearty & Seasonal'),
#  ("Ella's Kitchen Pouches", 'Soup'),
#  ("Ella's Kitchen Pouches", 'Pick and Mix Bowls'),
#  ("Ella's Kitchen Pouches", 'Smoothies'),
#  ("Ella's Kitchen Pouches", 'Cake'),
#  ("Ella's Kitchen Pouches", 'Mighty Protein'),
#  ("Ella's Kitchen Pouches", 'Chicken sand'),
#  ("Ella's Kitchen Pouches", 'Coke'),
#  ("Ella's Kitchen Pouches", 'Focaccia'),
#  ("Ella's Kitchen Pouches", 'Eggs'),
#  ("Ella's Kitchen Pouches", 'Dulce de Leche'),
#  ("Ella's Kitchen Pouches", 'Honey'),
#  ("Ella's Kitchen Pouches", 'The BART'),
#  ("Ella's Kitchen Pouches", 'Granola'),
#  ("Ella's Kitchen Pouches", 'Fairy Doors'),
#  ("Ella's Kitchen Pouches", 'Empanadas'),
#  ("Ella's Kitchen Pouches", 'Keeping It Local'),
#  ("Ella's Kitchen Pouches", 'Art Tray'),
#  ("Ella's Kitchen Pouches", 'Bowl Nic Pitt'),
#  ("Ella's Kitchen Pouches", 'Bread Pudding'),
#  ("Ella's Kitchen Pouches", 'Adjustment'),
#  ("Ella's Kitchen Pouches", 'Chimichurri Oil'),
#  ("Ella's Kitchen Pouches", 'Bacon'),
#  ("Ella's Kitchen Pouches", 'Spread'),
#  ("Ella's Kitchen Pouches", 'Kids biscuit'),
#  ("Ella's Kitchen Pouches", 'Siblings'),
#  ("Ella's Kitchen Pouches", 'Caramel bites'),
#  ("Ella's Kitchen Pouches", 'Jammie Dodgers'),
#  ("Ella's Kitchen Pouches", 'Olum & polenta'),
#  ("Ella's Kitchen Pouches", 'Polenta'),
#  ("Ella's Kitchen Pouches", 'The Nomad'),
#  ("Ella's Kitchen Pouches", 'Hack the stack'),
#  ("Ella's Kitchen Pouches", 'Bakewell'),
#  ("Ella's Kitchen Pouches", 'Lemon and coconut'),
#  ("Ella's Kitchen Pouches", 'Toast'),
#  ("Ella's Kitchen Pouches", 'Scone'),
#  ("Ella's Kitchen Pouches", 'Crepes'),
#  ("Ella's Kitchen Pouches", 'Vegan mincepie'),
#  ("Ella's Kitchen Pouches", 'Muesli'),
#  ("Ella's Kitchen Pouches", 'Crisps'),
#  ("Ella's Kitchen Pouches", 'Pintxos'),
#  ("Ella's Kitchen Pouches", 'Gingerbread syrup'),
#  ("Ella's Kitchen Pouches", 'Panatone'),
#  ("Ella's Kitchen Pouches", 'Brioche and salami'),
#  ("Ella's Kitchen Pouches", 'Afternoon with the baker'),
#  ("Ella's Kitchen Pouches", 'Salad'),
#  ("Ella's Kitchen Pouches", 'Chicken Stew'),
#  ("Ella's Kitchen Pouches", 'Spanish Brunch'),
#  ("Ella's Kitchen Pouches", 'Raspberry shortbread sandwich'),
#  ("Ella's Kitchen Pouches", 'Extra Salami or Feta'),
#  ("Ella's Kitchen Pouches", 'Duck egg'),
#  ("Ella's Kitchen Pouches", 'Baguette'),
#  ("Ella's Kitchen Pouches", "Valentine's card"),
#  ("Ella's Kitchen Pouches", 'Tshirt'),
#  ("Ella's Kitchen Pouches", 'Vegan Feast'),
#  ("Ella's Kitchen Pouches", 'Postcard'),
#  ("Ella's Kitchen Pouches", 'Nomad bag'),
#  ("Ella's Kitchen Pouches", 'Chocolates'),
#  ("Ella's Kitchen Pouches", 'Coffee granules '),
#  ("Ella's Kitchen Pouches", 'Drinking chocolate spoons '),
#  ("Ella's Kitchen Pouches", 'Christmas common'),
#  ("Ella's Kitchen Pouches", 'Argentina Night'),
#  ("Ella's Kitchen Pouches", 'Half slice Monster '),
#  ("Ella's Kitchen Pouches", 'Gift voucher'),
#  ("Ella's Kitchen Pouches", 'Cherry me Dried fruit'),
#  ("Ella's Kitchen Pouches", 'Mortimer'),
#  ("Ella's Kitchen Pouches", 'Raw bars'),
#  ("Ella's Kitchen Pouches", 'Tacos/Fajita'),
#  ('Victorian Sponge', 'Frittata'),
#  ('Victorian Sponge', 'Hearty & Seasonal'),
#  ('Victorian Sponge', 'Pick and Mix Bowls'),
#  ('Victorian Sponge', 'Smoothies'),
#  ('Victorian Sponge', 'Mighty Protein'),
#  ('Victorian Sponge', 'Chicken sand'),
#  ('Victorian Sponge', 'Coke'),
#  ('Victorian Sponge', 'My-5 Fruit Shoot'),
#  ('Victorian Sponge', 'Focaccia'),
#  ('Victorian Sponge', 'Sandwich'),
#  ('Victorian Sponge', 'Eggs'),
#  ('Victorian Sponge', 'Brownie'),
#  ('Victorian Sponge', 'Dulce de Leche'),
#  ('Victorian Sponge', 'Honey'),
#  ('Victorian Sponge', 'The BART'),
#  ('Victorian Sponge', 'Granola'),
#  ('Victorian Sponge', 'Fairy Doors'),
#  ('Victorian Sponge', 'Empanadas'),
#  ('Victorian Sponge', 'Keeping It Local'),
#  ('Victorian Sponge', 'Art Tray'),
#  ('Victorian Sponge', 'Bowl Nic Pitt'),
#  ('Victorian Sponge', 'Bread Pudding'),
#  ('Victorian Sponge', 'Adjustment'),
#  ('Victorian Sponge', 'Truffles'),
#  ('Victorian Sponge', 'Chimichurri Oil'),
#  ('Victorian Sponge', 'Bacon'),
#  ('Victorian Sponge', 'Spread'),
#  ('Victorian Sponge', 'Kids biscuit'),
#  ('Victorian Sponge', 'Siblings'),
#  ('Victorian Sponge', 'Caramel bites'),
#  ('Victorian Sponge', 'Jammie Dodgers'),
#  ('Victorian Sponge', 'Tiffin'),
#  ('Victorian Sponge', 'Olum & polenta'),
#  ('Victorian Sponge', 'Polenta'),
#  ('Victorian Sponge', 'The Nomad'),
#  ('Victorian Sponge', 'Hack the stack'),
#  ('Victorian Sponge', 'Bakewell'),
#  ('Victorian Sponge', 'Lemon and coconut'),
#  ('Victorian Sponge', 'Toast'),
#  ('Victorian Sponge', 'Scone'),
#  ('Victorian Sponge', 'Crepes'),
#  ('Victorian Sponge', 'Vegan mincepie'),
#  ('Victorian Sponge', 'Bare Popcorn'),
#  ('Victorian Sponge', 'Muesli'),
#  ('Victorian Sponge', 'Crisps'),
#  ('Victorian Sponge', 'Pintxos'),
#  ('Victorian Sponge', 'Gingerbread syrup'),
#  ('Victorian Sponge', 'Panatone'),
#  ('Victorian Sponge', 'Brioche and salami'),
#  ('Victorian Sponge', 'Afternoon with the baker'),
#  ('Victorian Sponge', 'Salad'),
#  ('Victorian Sponge', 'Chicken Stew'),
#  ('Victorian Sponge', 'Spanish Brunch'),
#  ('Victorian Sponge', 'Raspberry shortbread sandwich'),
#  ('Victorian Sponge', 'Extra Salami or Feta'),
#  ('Victorian Sponge', 'Duck egg'),
#  ('Victorian Sponge', 'Baguette'),
#  ('Victorian Sponge', "Valentine's card"),
#  ('Victorian Sponge', 'Tshirt'),
#  ('Victorian Sponge', 'Vegan Feast'),
#  ('Victorian Sponge', 'Postcard'),
#  ('Victorian Sponge', 'Nomad bag'),
#  ('Victorian Sponge', 'Chocolates'),
#  ('Victorian Sponge', 'Coffee granules '),
#  ('Victorian Sponge', 'Drinking chocolate spoons '),
#  ('Victorian Sponge', 'Christmas common'),
#  ('Victorian Sponge', 'Argentina Night'),
#  ('Victorian Sponge', 'Half slice Monster '),
#  ('Victorian Sponge', 'Gift voucher'),
#  ('Victorian Sponge', 'Cherry me Dried fruit'),
#  ('Victorian Sponge', 'Mortimer'),
#  ('Victorian Sponge', 'Raw bars'),
#  ('Victorian Sponge', 'Tacos/Fajita'),
#  ('Frittata', 'Pick and Mix Bowls'),
#  ('Frittata', 'Mighty Protein'),
#  ('Frittata', 'My-5 Fruit Shoot'),
#  ('Frittata', 'Focaccia'),
#  ('Frittata', 'Eggs'),
#  ('Frittata', 'Dulce de Leche'),
#  ('Frittata', 'Honey'),
#  ('Frittata', 'The BART'),
#  ('Frittata', 'Granola'),
#  ('Frittata', 'Fairy Doors'),
#  ('Frittata', 'Empanadas'),
#  ('Frittata', 'Bread Pudding'),
#  ('Frittata', 'Adjustment'),
#  ('Frittata', 'Chimichurri Oil'),
#  ('Frittata', 'Bacon'),
#  ('Frittata', 'Spread'),
#  ('Frittata', 'Kids biscuit'),
#  ('Frittata', 'Siblings'),
#  ('Frittata', 'Caramel bites'),
#  ('Frittata', 'Tiffin'),
#  ('Frittata', 'Olum & polenta'),
#  ('Frittata', 'Polenta'),
#  ('Frittata', 'Hack the stack'),
#  ('Frittata', 'Bakewell'),
#  ('Frittata', 'Lemon and coconut'),
#  ('Frittata', 'Crepes'),
#  ('Frittata', 'Bare Popcorn'),
#  ('Frittata', 'Muesli'),
#  ('Frittata', 'Pintxos'),
#  ('Frittata', 'Gingerbread syrup'),
#  ('Frittata', 'Panatone'),
#  ('Frittata', 'Brioche and salami'),
#  ('Frittata', 'Afternoon with the baker'),
#  ('Frittata', 'Chicken Stew'),
#  ('Frittata', 'Spanish Brunch'),
#  ('Frittata', 'Raspberry shortbread sandwich'),
#  ('Frittata', 'Duck egg'),
#  ('Frittata', 'Baguette'),
#  ('Frittata', "Valentine's card"),
#  ('Frittata', 'Tshirt'),
#  ('Frittata', 'Vegan Feast'),
#  ('Frittata', 'Postcard'),
#  ('Frittata', 'Nomad bag'),
#  ('Frittata', 'Chocolates'),
#  ('Frittata', 'Coffee granules '),
#  ('Frittata', 'Drinking chocolate spoons '),
#  ('Frittata', 'Christmas common'),
#  ('Frittata', 'Argentina Night'),
#  ('Frittata', 'Half slice Monster '),
#  ('Frittata', 'Gift voucher'),
#  ('Frittata', 'Cherry me Dried fruit'),
#  ('Frittata', 'Mortimer'),
#  ('Frittata', 'Raw bars'),
#  ('Frittata', 'Tacos/Fajita'),
#  ('Hearty & Seasonal', 'Chicken sand'),
#  ('Hearty & Seasonal', 'My-5 Fruit Shoot'),
#  ('Hearty & Seasonal', 'Eggs'),
#  ('Hearty & Seasonal', 'Dulce de Leche'),
#  ('Hearty & Seasonal', 'Honey'),
#  ('Hearty & Seasonal', 'The BART'),
#  ('Hearty & Seasonal', 'Granola'),
#  ('Hearty & Seasonal', 'Fairy Doors'),
#  ('Hearty & Seasonal', 'Empanadas'),
#  ('Hearty & Seasonal', 'Bread Pudding'),
#  ('Hearty & Seasonal', 'Adjustment'),
#  ('Hearty & Seasonal', 'Chimichurri Oil'),
#  ('Hearty & Seasonal', 'Bacon'),
#  ('Hearty & Seasonal', 'Spread'),
#  ('Hearty & Seasonal', 'Kids biscuit'),
#  ('Hearty & Seasonal', 'Siblings'),
#  ('Hearty & Seasonal', 'Caramel bites'),
#  ('Hearty & Seasonal', 'Jammie Dodgers'),
#  ('Hearty & Seasonal', 'Olum & polenta'),
#  ('Hearty & Seasonal', 'Polenta'),
#  ('Hearty & Seasonal', 'The Nomad'),
#  ('Hearty & Seasonal', 'Hack the stack'),
#  ('Hearty & Seasonal', 'Bakewell'),
#  ('Hearty & Seasonal', 'Lemon and coconut'),
#  ('Hearty & Seasonal', 'Toast'),
#  ('Hearty & Seasonal', 'Crepes'),
#  ('Hearty & Seasonal', 'Vegan mincepie'),
#  ('Hearty & Seasonal', 'Bare Popcorn'),
#  ('Hearty & Seasonal', 'Muesli'),
#  ('Hearty & Seasonal', 'Crisps'),
#  ('Hearty & Seasonal', 'Pintxos'),
#  ('Hearty & Seasonal', 'Gingerbread syrup'),
#  ('Hearty & Seasonal', 'Panatone'),
#  ('Hearty & Seasonal', 'Brioche and salami'),
#  ('Hearty & Seasonal', 'Afternoon with the baker'),
#  ('Hearty & Seasonal', 'Salad'),
#  ('Hearty & Seasonal', 'Chicken Stew'),
#  ('Hearty & Seasonal', 'Spanish Brunch'),
#  ('Hearty & Seasonal', 'Raspberry shortbread sandwich'),
#  ('Hearty & Seasonal', 'Extra Salami or Feta'),
#  ('Hearty & Seasonal', 'Duck egg'),
#  ('Hearty & Seasonal', 'Baguette'),
#  ('Hearty & Seasonal', "Valentine's card"),
#  ('Hearty & Seasonal', 'Tshirt'),
#  ('Hearty & Seasonal', 'Vegan Feast'),
#  ('Hearty & Seasonal', 'Postcard'),
#  ('Hearty & Seasonal', 'Nomad bag'),
#  ('Hearty & Seasonal', 'Chocolates'),
#  ('Hearty & Seasonal', 'Coffee granules '),
#  ('Hearty & Seasonal', 'Drinking chocolate spoons '),
#  ('Hearty & Seasonal', 'Christmas common'),
#  ('Hearty & Seasonal', 'Argentina Night'),
#  ('Hearty & Seasonal', 'Half slice Monster '),
#  ('Hearty & Seasonal', 'Gift voucher'),
#  ('Hearty & Seasonal', 'Cherry me Dried fruit'),
#  ('Hearty & Seasonal', 'Mortimer'),
#  ('Hearty & Seasonal', 'Raw bars'),
#  ('Hearty & Seasonal', 'Tacos/Fajita'),
#  ('Soup', 'Chicken sand'),
#  ('Soup', 'Eggs'),
#  ('Soup', 'Dulce de Leche'),
#  ('Soup', 'Honey'),
#  ('Soup', 'The BART'),
#  ('Soup', 'Granola'),
#  ('Soup', 'Fairy Doors'),
#  ('Soup', 'Adjustment'),
#  ('Soup', 'Chimichurri Oil'),
#  ('Soup', 'Bacon'),
#  ('Soup', 'Spread'),
#  ('Soup', 'Siblings'),
#  ('Soup', 'Caramel bites'),
#  ('Soup', 'Jammie Dodgers'),
#  ('Soup', 'Olum & polenta'),
#  ('Soup', 'Polenta'),
#  ('Soup', 'Hack the stack'),
#  ('Soup', 'Lemon and coconut'),
#  ('Soup', 'Crepes'),
#  ('Soup', 'Vegan mincepie'),
#  ('Soup', 'Bare Popcorn'),
#  ('Soup', 'Muesli'),
#  ('Soup', 'Crisps'),
#  ('Soup', 'Pintxos'),
#  ('Soup', 'Gingerbread syrup'),
#  ('Soup', 'Panatone'),
#  ('Soup', 'Brioche and salami'),
#  ('Soup', 'Raspberry shortbread sandwich'),
#  ('Soup', 'Baguette'),
#  ('Soup', "Valentine's card"),
#  ('Soup', 'Tshirt'),
#  ...]

# %%
len(df["Item"].unique())
# Out:
# 95

# %%
drink = ['Hot chocolate', 'Coffee','Tea', 'Mineral water', 'Juice', 'Smoothies', 'Coke']
food = ['Bread', 'Scandinavian', 'Jam', 'Cookies','Muffin', 'Pastry','Medialuna', 'Tartine', 'Frittata', 'Hearty & Seasonal', 'Soup', 'Chicken sand','Cake','Focaccia','Sandwich', 'Alfajores', 'Eggs', 'Brownie', 'Dulce de Leche', 'Honey', 'Granola', 'Empanadas', 'Bread Pudding', 'Truffles', 'Bacon', 'Spread', 'Kids biscuit', 'Caramel bites', 'Jammie Dodgers', 'Polenta', 'Bakewell', 'Lemon and coconut', 'Toast', 'Scone', 'Crepes', 'Vegan mincepie', 'Bare Popcorn', 'Muesli', 'Crisps', 'Pintxos', 'Gingerbread syrup', 'Panatone', 'Brioche and salami', 'Salad', 'Chicken Stew', 'Spanish Brunch', 'Raspberry shortbread sandwich', 'Extra Salami or Feta', 'Duck egg', 'Baguette', 'Chocolates', 'Cherry me Dried fruit', 'Tacos/Fajita']
unknown = ['NONE', 'Basket', 'Farm House', 'Fudge', "Ella's Kitchen Pouches", 'Victorian Sponge', 'Pick and Mix Bowls', 'Mighty Protein', 'My-5 Fruit Shoot', 'The BART', 'Fairy Doors', 'Keeping It Local', 'Art Tray', 'Bowl Nic Pitt', 'Adjustment', 'Chimichurri Oil', 'Siblings', 'Tiffin', 'Olum & polenta', 'The Nomad', 'Hack the stack', 'Afternoon with the baker', "Valentine's card", 'Tshirt', 'Vegan Feast', 'Postcard', 'Nomad bag', 'Coffee granules ', 'Drinking chocolate spoons ', 'Christmas common', 'Argentina Night', 'Half slice Monster ', 'Gift voucher', 'Mortimer', 'Raw bars']

# %%
print(len(drink))
print(len(food))
print(len(unknown))
# Out:
# 7
# 53
# 35

# %%
def createCategory(items):
    item_category = []
    for item in items:
        if item in food:
            item_category.append("food")
        elif item in unknown:
            item_category.append("unknown")
        elif item in drink:
            item_category.append("drink")
    return item_category

# %%
df["Item_Category"]  = createCategory(df['Item'])

# %%
df.head()
# Out:
#    Year  Month  Day Weekday  Hour  Min  Sec  Transaction           Item  \
# 0  2016     10   30  Sunday     9   58   11            1          Bread
# 1  2016     10   30  Sunday    10    5   34            2   Scandinavian
# 2  2016     10   30  Sunday    10    5   34            2   Scandinavian
# 3  2016     10   30  Sunday    10    7   57            3  Hot chocolate
# 4  2016     10   30  Sunday    10    7   57            3            Jam
#
#    Item_Price   Period Item_Category
# 0        7.66  morning          food
# 1        5.33  morning          food
# 2        5.33  morning          food
# 3        2.81  morning         drink
# 4        2.81  morning          food

# %%
trans_per_day = df.groupby(['Year', 'Month', 'Day', 'Weekday'])['Transaction'].count()

# %%
df_trans_per_day = trans_per_day.to_frame()

# %%
ave_trans_for_weekday = df_trans_per_day.groupby('Weekday')['Transaction'].mean()

# %%
weekdays = df['Weekday'].unique()
barista_dict = {}
for weekday in weekdays:
    barista_dict[weekday] = int(round(ave_trans_for_weekday[weekday] / 60.0))

# %%
barista_dict
# Out:
# {'Sunday': 2,
#  'Monday': 2,
#  'Tuesday': 2,
#  'Wednesday': 2,
#  'Thursday': 2,
#  'Friday': 2,
#  'Saturday': 3}

# %%
food_price = df.loc[df['Item_Category'] == 'food'].groupby(['Item'])['Item_Price'].mean()

# %%
food_price
# Out:
# Item
# Alfajores                         9.58
# Bacon                             8.97
# Baguette                          4.73
# Bakewell                          5.43
# Bare Popcorn                      4.42
# Bread                             7.66
# Bread Pudding                     9.68
# Brioche and salami                3.62
# Brownie                           6.44
# Cake                              6.04
# Caramel bites                     4.53
# Cherry me Dried fruit             5.64
# Chicken Stew                      3.11
# Chicken sand                      8.97
# Chocolates                        3.21
# Cookies                           1.39
# Crepes                            8.87
# Crisps                            4.12
# Duck egg                          9.88
# Dulce de Leche                    9.27
# Eggs                              7.35
# Empanadas                         5.94
# Extra Salami or Feta              2.30
# Focaccia                          7.35
# Frittata                          7.45
# Gingerbread syrup                 4.63
# Granola                           3.62
# Hearty & Seasonal                 3.72
# Honey                             9.68
# Jam                               2.81
# Jammie Dodgers                    9.58
# Kids biscuit                      5.13
# Lemon and coconut                 3.01
# Medialuna                         2.71
# Muesli                            8.97
# Muffin                            7.96
# Panatone                          2.00
# Pastry                           10.18
# Pintxos                          10.59
# Polenta                           9.07
# Raspberry shortbread sandwich     9.68
# Salad                            10.99
# Sandwich                          0.99
# Scandinavian                      5.33
# Scone                             8.26
# Soup                              1.09
# Spanish Brunch                    9.27
# Spread                            3.82
# Tacos/Fajita                      7.96
# Tartine                           1.80
# Toast                             8.67
# Truffles                          4.53
# Vegan mincepie                    6.85
# Name: Item_Price, dtype: float64

# %%
ave_food_price = food_price.mean()

# %%
ave_food_price
# Out:
# 6.2047169811320755

# %%
sales_for_category = df['Item_Price'].groupby(df['Item_Category']).sum()

# %%
drink_sales = sales_for_category['drink']
food_sales = sales_for_category['food']

# %%
def createTop5Dict(time):
    items_for_time = df.groupby(time)['Item'].value_counts()
    times = np.sort(df[time].unique())
    popularity = {}
    for t in times:
        if len(items_for_time[t]) >= 5:
            popularity[t] = items_for_time[t][:5]
        else:
            popularity[t] = items_for_time[t][:]
    return popularity

def createBottom5Dict(time):
    items_for_time = df.groupby(time)['Item'].value_counts()
    times = np.sort(df[time].unique())
    popularity = {}
    for t in times:
        if len(items_for_time[t]) >= 5:
            popularity[t] = items_for_time[t][-1:-6:-1]
        else:
            popularity[t] = items_for_time[t][-1::-1]
    return popularity

# %%
top_hour = createTop5Dict('Hour')

# %%
bottom_hour = createBottom5Dict('Hour')

# %%
top_weekday = createTop5Dict('Weekday')

# %%
bottom_weekday = createBottom5Dict('Weekday')

# %%
top_peiod = createTop5Dict('Period')

# %%
bottom_peiod = createBottom5Dict('Period')

# %%
items_for_time = df.groupby("Hour")['Item'].value_counts()

# %%
items_for_time
# Out:
# Hour  Item
# 1     Bread                         1
# 7     Coffee                       13
#       Medialuna                     6
#       Bread                         2
#       Pastry                        2
#       NONE                          1
#       Toast                         1
# 8     Coffee                      199
#       Bread                       171
#       Pastry                       57
#       Medialuna                    43
#       NONE                         24
#       Toast                        23
#       Tea                          21
#       Farm House                   13
#       Cookies                      12
#       Hot chocolate                 9
#       Baguette                      8
#       Cake                          8
#       Jam                           7
#       Scandinavian                  6
#       Scone                         6
#       Brownie                       5
#       Sandwich                      5
#       Alfajores                     4
#       Christmas common              4
#       Jammie Dodgers                4
#       Juice                         4
#       Afternoon with the baker      3
#       Keeping It Local              3
#                                  ...
# 19    Hot chocolate                 3
#       Postcard                      3
#       Tea                           3
#       Bread                         2
#       Pintxos                       2
#       Adjustment                    1
#       Brownie                       1
#       Fudge                         1
#       Jammie Dodgers                1
#       Juice                         1
#       Medialuna                     1
#       Truffles                      1
#       Vegan mincepie                1
# 20    Postcard                      7
#       Tshirt                        5
#       Pintxos                       4
#       Coffee                        1
#       Coke                          1
#       Dulce de Leche                1
#       Fudge                         1
#       Nomad bag                     1
#       Vegan mincepie                1
# 21    Hot chocolate                 2
#       Vegan Feast                   1
# 22    Vegan Feast                   5
#       Juice                         1
#       Mineral water                 1
#       Scandinavian                  1
# 23    Valentine's card              2
#       Vegan Feast                   1
# Name: Item, Length: 651, dtype: int64

# %%
drinks_per_trans = df.loc[df['Item_Category'] == 'drink'].groupby('Transaction')['Item_Category'].count()

# %%
frequency_groupsize = drinks_per_trans.value_counts()

# %%
total_transactions = frequency_groupsize.sum()
groupsize_percentage = {}
for i in frequency_groupsize.index :
    groupsize_percentage[i] = frequency_groupsize[i] / total_transactions * 100

# %%
groupsize_percentage
# Out:
# {1: 66.76237122107752,
#  2: 27.7824691775038,
#  3: 4.7289309238304345,
#  4: 0.5911163654788043,
#  5: 0.13511231210944097}

# %%
df["Transaction"].unique()
# Out:
# array([   1,    2,    3, ..., 9682, 9683, 9684])

# %%
frequency_groupsize
# Out:
# 1    3953
# 2    1645
# 3     280
# 4      35
# 5       8
# Name: Item_Category, dtype: int64
